# %% [markdown]
# <img src="./images/DLI_Header.png" style="width: 400px;">

# %% [markdown]
# # 5.0 Multi-Nodes Distributed Training for Computer Vision
#
# In this notebook, we will learn how to train a simple Image Classifier in distributed mode.
# We will first implement a vanilla pipeline parallel distribution. Then, we will use Microsoft's [DeepSpeed Library](https://www.deepspeed.ai/) for model distribution and optimization techniques.
#
# ## The goals
#
# The goals of this notebook are to:
# * Learn how to train a vanilla CNN
# * Port the code to DeepSpeed library
# * Scale training using Data parallel distribution
# * Optimize training with DeepSpeed autotuning and Zero Redundancy Optimizer
#
#
# **[5.1 Convolutional Neural Network for Image Classification on CIFAR-10](#1.1-The-hardware-overview)<br>**
# &nbsp;&nbsp;&nbsp;&nbsp;[5.1.1 The dataset](#1.1.3-Check-The-Interconnect-Topology)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[5.1.2 Convolutional Neural Network](#1.1.3-Check-The-Interconnect-Topology)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[5.1.3 Naive Model Distribution](#1.1.3-Check-The-Interconnect-Topology)<br>
# **[5.2 Distributed Training with DeepSpeed](#1.1-The-hardware-overview)<br>**
# &nbsp;&nbsp;&nbsp;&nbsp;[5.2.1 Make the code run with DeepSpeed](#1.1.3-Check-The-Interconnect-Topology)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[5.2.2 Scale-out training with Data Parallelism](#1.1.3-Check-The-Interconnect-Topology)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;[5.2.3 Zero Redundancy Optimizer ](#1.1.3-Check-The-Interconnect-Topology)<br>
#
# ### Cancel Previous Running/Pending Jobs
#
# Before moving on, check that no jobs are still running or waiting on the SLURM queue. Let's check the SLURM jobs queue by executing the following cell:

# %%
# Check the SLURM jobs queue 
# !squeue
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)

# %% [markdown]
# If there are still jobs running or pending, execute the following cell to cancel all the user's jobs using the `scancel` command.

# %%
# Cancel admin user jobs
# !scancel -u $USER

# Check again the SLURM jobs queue (should be either empty, or the status TS column should be CG)
# !squeue
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)

# %% [markdown]
# ---
# # 5.1 Convolutional Neural Network for Image Classification on CIFAR-10
#
# ## 5.1.1 The dataset
#
#
# The [CIFAR-10 Dataset](https://www.cs.toronto.edu/~kriz/cifar.html) consists of 60K images (50K for training and 10K for testing). Images are 32 by 32 pixels labelled with 10 classes: plane, car, bird, cat, deer, dog, frog, horse, ship and truck.
# In this lab, we will train a simple Convolutional Neural Network to classify CIFAR-10 images.
#
# To download the dataset, we will use the [Torchvision](https://pytorch.org/vision/stable/index.html) package, a Pytorch library that contains popular datasets, model architectures, and common image transformations for Computer Vision.
# <img src="images/CIFAR-10.jpg" width="350" />
#
# Let's first import the relevant libraries by executing the next cell.

# %%
# import the relevant libraries
import torch
import torchvision
from IPython.display import display_html

def restartkernel() :
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)

# define an image transform 
transform = torchvision.transforms.Compose([torchvision.transforms.ToTensor(),torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

# %% [markdown]
# Execute the next 2 cells to download the training and test CIFAR10 corpus.

# %%
# Download the CIFAR10 training dataset
trainset = torchvision.datasets.CIFAR10(root='./data',
                                        train=True,
                                        download=True,
                                        transform=transform)
trainloader = torch.utils.data.DataLoader(trainset,
                                          batch_size=64,
                                          shuffle=True,
                                          num_workers=2)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data

# %%
# Download the CIFAR10 test dataset
testset = torchvision.datasets.CIFAR10(root='./data',
                                       train=False,
                                       download=True,
                                       transform=transform)

testloader = torch.utils.data.DataLoader(testset,
                                         batch_size=64,
                                         shuffle=False,
                                         num_workers=2)
# Out:
# Files already downloaded and verified

# %% [markdown]
# Let's have a look at some examples:

# %%
# Show some random training images
import matplotlib.pyplot as plt
import numpy as np

def imshow(images, labels):
    for i in range(8): 
        img = images[i] / 2 + 0.5
        npimg = img.numpy()
        plt.subplot(2,4,i+1)
        plt.imshow(np.transpose(npimg, (1, 2 , 0)));
        plt.axis('off');
        plt.title(classes[labels[i]])

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# get some training images
dataiter = iter(trainloader)
images, labels = dataiter.next()
# Show images
imshow(images,labels)

# %% [markdown]
# ## 5.1.2 Convolutional Neural Network
#
# Let's define a neural network with 2 convolutional layers, first followed by a pooling layer then 3 fully connected layers.

# %%
# Define the CNN
import torch.nn as nn
import torch.nn.functional as F

class CNN_Net(nn.Module):
    def __init__(self):
        super(CNN_Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

cnn_net = CNN_Net()

# %%
# Copy the model to GPU 0
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
cnn_net.to(device)
# Out:
# CNN_Net(
#   (conv1): Conv2d(3, 6, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %%
# Let's have a look at the Convolutional Neural Network
from torchsummary import summary
summary(cnn_net,input_size=(3,32,32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 6, 28, 28]             456
#          MaxPool2d-2            [-1, 6, 14, 14]               0
#             Conv2d-3           [-1, 16, 10, 10]           2,416
#          MaxPool2d-4             [-1, 16, 5, 5]               0
#             Linear-5                  [-1, 120]          48,120
#             Linear-6                   [-1, 84]          10,164
#             Linear-7                   [-1, 10]             850
# ================================================================
# Total params: 62,006
# Trainable params: 62,006
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.06
# Params size (MB): 0.24
# Estimated Total Size (MB): 0.31
# ----------------------------------------------------------------

# %% [markdown]
# Let's define the optimizer and hyperparameters. We will use the Stochastic Gradient Descent (SGD) with momentum optimizer.

# %%
# Define the hyperparameters
import torch.optim as optim
from torch.utils.tensorboard import SummaryWriter 

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(cnn_net.parameters(), lr=0.001,momentum=0.9, weight_decay=5e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)

# Tensorboard event recording directory 
writer = SummaryWriter('megatron/tensorboard/cifar10')

log_interval=100
batch_size=64
epochs=2

# %%
# Train the CNN
for epoch in range(epochs): 
    running_loss = 0.0
    correct = 0
    total = 0
    for i, data in enumerate(trainloader):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data[0].to(device), data[1].to(device)
        
        # zero the parameter gradients
        optimizer.zero_grad()
        
        # Forward pass
        outputs = cnn_net(inputs)
        loss = criterion(outputs, labels)
        
        # Backward pass
        loss.backward()
        optimizer.step()     
        
        # print the loss and accuracy metrics log_interval mini-batches
        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        if i % log_interval == (log_interval - 1):  
            print('[epoch %d, iterations %5d] loss: %.3f accuracy: %2f %%' %  (epoch , i + 1, running_loss / log_interval, 100.*correct/total))
            writer.add_scalar("Training Cross Entropy Loss", running_loss / log_interval, i + 1)
            writer.add_scalar("Training Accuracy", 100.*correct/total, i + 1)
            running_loss = 0.0
    # print the last iterations 
    print('[epoch %d, iterations %5d] loss: %.3f accuracy: %2f %%' %  (epoch , i + 1, running_loss / ((i % log_interval) + 1), 100.*correct/total))
    writer.add_scalar("Training Cross Entropy Loss", running_loss / ((i % log_interval) + 1), i + 1)
    writer.add_scalar("Training Accuracy", 100.*correct/total, i + 1)

print('Training Done')
writer.add_graph(cnn_net, inputs)
writer.flush()
writer.close()
# Out:
# [epoch 0, iterations   100] loss: 2.303 accuracy: 14.218750 %
# [epoch 0, iterations   200] loss: 2.300 accuracy: 15.070312 %
# [epoch 0, iterations   300] loss: 2.299 accuracy: 14.656250 %
# [epoch 0, iterations   400] loss: 2.293 accuracy: 14.777344 %
# [epoch 0, iterations   500] loss: 2.283 accuracy: 14.912500 %
# [epoch 0, iterations   600] loss: 2.269 accuracy: 14.924479 %
# [epoch 0, iterations   700] loss: 2.243 accuracy: 15.118304 %
# [epoch 0, iterations   782] loss: 2.216 accuracy: 15.474000 %
# [epoch 1, iterations   100] loss: 2.192 accuracy: 21.187500 %
# [epoch 1, iterations   200] loss: 2.167 accuracy: 20.843750 %
# [epoch 1, iterations   300] loss: 2.141 accuracy: 21.239583 %
# [epoch 1, iterations   400] loss: 2.122 accuracy: 21.726562 %
# [epoch 1, iterations   500] loss: 2.099 accuracy: 22.259375 %
# [epoch 1, iterations   600] loss: 2.068 accuracy: 22.723958 %
# [epoch 1, iterations   700] loss: 2.036 accuracy: 23.330357 %
# [epoch 1, iterations   782] loss: 2.018 accuracy: 23.738000 %
# Training Done

# %% [markdown]
# ### Monitor Training and Inspect the Model on Tensorboard
#
# We set the arguments for recording Tensorboard events in the previous CNN training. The training loss is available under the name `cifar10`. We can also visualize the model and navigate throughout its layers on the "Graphs" tab.
#
# <img src="images/CNN.png" width="750"/>
#
# Execute the next cell to create a link to Tensorboard for your browser. Then, click the link to see graphs of experiment metrics saved in the specified `Tensorboard` directory.

# %%
# %%js
# const href = window.location.hostname +'/tensorboard/';
# let a = document.createElement('a');
# let link = document.createTextNode('Open Tensorboard!');
# a.appendChild(link);
# a.href = "http://" + href;
# a.style.color = "navy"
# a.target = "_blank"
# element.append(a);

# %% [markdown]
# ### Evaluate The Trained Model
#
# Let's evaluate the trained model on the CIFAR-10 test dataset. Execute the following cell to evaluate the accuracy on the test set. Accuracy detail per class will also be shown.

# %%
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))
correct = 0
total = 0
with torch.no_grad():
    for data in testloader:
        images, labels = data
        outputs = cnn_net(images.to(device))
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels.to(device)).sum().item()
        c = (predicted == labels.to(device)).squeeze()
        for i in range(4):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

print('Accuracy of the network on the 10000 test images: %2f %%' %
      (100 * correct / total))
for i in range(10):
    print('Accuracy of %5s : %2f %%' %
          (classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of the network on the 10000 test images: 28.750000 %
# Accuracy of plane : 37.500000 %
# Accuracy of   car : 36.000000 %
# Accuracy of  bird : 3.797468 %
# Accuracy of   cat : 20.547945 %
# Accuracy of  deer : 3.636364 %
# Accuracy of   dog : 30.508475 %
# Accuracy of  frog : 71.428571 %
# Accuracy of horse : 14.062500 %
# Accuracy of  ship : 34.482759 %
# Accuracy of truck : 39.743590 %

# %% [markdown]
# # 5.1.3 Naive Model Distribution
#
# Let's now implement a naive pipeline parallel distribution of the previous CNN model. To do so, we need to explicitly place each layer into the device and implement the forward pass, accordingly moving the corresponding outputs to match devices accordingly.

# %% [markdown]
# We will run the CNN model on two GPUs by placing: conv1 + pooling on GPU0 and conv2 + fc1 + fc2+ fc3 on GPU1.
# We will use torch *[TORCH.TENSOR.TO](https://pytorch.org/docs/stable/generated/torch.Tensor.to.html#torch.Tensor.to)* to convert tensors to cuda and place them to the desired device.
#
# Have a look at modified class on the defined `Net_Parallel` class:

# %%
# Define the CNN
import torch.nn as nn
import torch.nn.functional as F

class Net_Parallel(nn.Module):
    def __init__(self):
        super(Net_Parallel, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5).to('cuda:0')               # Changed here
        self.pool = nn.MaxPool2d(2, 2).to('cuda:0')                # Changed here
        self.conv2 = nn.Conv2d(6, 16, 5).to('cuda:1')              # Changed here
        self.fc1 = nn.Linear(16 * 5 * 5, 120).to('cuda:1')         # Changed here
        self.fc2 = nn.Linear(120, 84).to('cuda:1')                 # Changed here
        self.fc3 = nn.Linear(84, 10).to('cuda:1')                  # Changed here

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x.to('cuda:0'))))          # Changed here
        x = self.pool(F.relu(self.conv2(x.to('cuda:1'))))          # Changed here
        x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

cnn_net_pp = Net_Parallel()

# %% [markdown]
# Similar to the previous training execution, run the next 2 cells to define the optimizer/hyperparameters and then launch the training.

# %%
# Define the hyperparameters
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(cnn_net_pp.parameters(), lr=0.001,momentum=0.9, weight_decay=5e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)

# Tensorboard event recording directory 
writer_pp = SummaryWriter('megatron/tensorboard/cifar10_PP')                 

log_interval=100
batch_size=64
epochs=2

# %% [markdown]
# You can check the GPUs activity by running the next cell to open a terminal and the watch `nvidia-smi` command.

# %%
# %%html
#
# <pre>
#    Step 1: Open a terminal session by following the <a href="", data-commandlinker-command="terminal:create-new">Terminal link</a>
#    Step 2: Check the GPUs: <font color="green">watch nvidia-smi</font>
# </pre
# Out:
# <pre>
#    Step 1: Open a terminal session by following the <a href="", data-commandlinker-command="terminal:create-new">Terminal link</a>
#    Step 2: Check the GPUs: <font color="green">watch nvidia-smi</font>
# </pre

# %% [markdown]
# Keep the terminal window opened and execute the next training.

# %%
# Train the CNN with pipeline parallel
for epoch in range(epochs): 
    running_loss = 0.0
    correct = 0
    total = 0
    for i, data in enumerate(trainloader):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data[0].to(device), data[1].to(device)
        
        # zero the parameter gradients
        optimizer.zero_grad()
        
        # Forward pass
        outputs = cnn_net_pp(inputs.to('cuda:0'))                                # Changed here
        loss = criterion(outputs, labels.to('cuda:1'))                           # Changed here
        # Backward pass
        loss.backward()
        optimizer.step()
        torch.cuda.reset_max_memory_allocated(0)
        # print the loss and accuracy metrics log_interval mini-batches
        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels.to('cuda:1')).sum().item()                 # Changed here
        if i % log_interval == (log_interval - 1):  
            print('[epoch %d, iterations %5d] loss: %.3f accuracy: %2f %%' %  (epoch , i + 1, running_loss / log_interval, 100.*correct/total))
            writer_pp.add_scalar("Training Cross Entropy Loss", running_loss / log_interval, i + 1)
            writer_pp.add_scalar("Training Accuracy", 100.*correct/total, i + 1)
            running_loss = 0.0
    # print the last iterations 
    print('[epoch %d, iterations %5d] loss: %.3f accuracy: %2f %%' %  (epoch , i + 1, running_loss / ((i % log_interval) + 1), 100.*correct/total))
    writer.add_scalar("Training Cross Entropy Loss", running_loss / ((i % log_interval) + 1), i + 1)
    writer.add_scalar("Training Accuracy", 100.*correct/total, i + 1)

print('Training Done')
writer_pp.add_graph(cnn_net_pp, inputs)
writer_pp.flush()
writer_pp.close()
# Out:
# /opt/conda/lib/python3.8/site-packages/torch/cuda/memory.py:271: FutureWarning: torch.cuda.reset_max_memory_allocated now calls torch.cuda.reset_peak_memory_stats, which resets /all/ peak memory stats.
#   warnings.warn(
# [epoch 0, iterations   100] loss: 2.303 accuracy: 10.187500 %
# [epoch 0, iterations   200] loss: 2.303 accuracy: 10.601562 %
# [epoch 0, iterations   300] loss: 2.303 accuracy: 10.729167 %
# [epoch 0, iterations   400] loss: 2.302 accuracy: 10.851562 %
# [epoch 0, iterations   500] loss: 2.300 accuracy: 10.934375 %
# [epoch 0, iterations   600] loss: 2.298 accuracy: 11.054688 %
# [epoch 0, iterations   700] loss: 2.295 accuracy: 11.196429 %
# [epoch 0, iterations   782] loss: 2.292 accuracy: 11.410000 %
# [epoch 1, iterations   100] loss: 2.287 accuracy: 15.812500 %
# [epoch 1, iterations   200] loss: 2.277 accuracy: 17.250000 %
# [epoch 1, iterations   300] loss: 2.263 accuracy: 17.828125 %
# [epoch 1, iterations   400] loss: 2.226 accuracy: 18.398438 %
# [epoch 1, iterations   500] loss: 2.172 accuracy: 18.971875 %
# [epoch 1, iterations   600] loss: 2.121 accuracy: 19.395833 %
# [epoch 1, iterations   700] loss: 2.077 accuracy: 19.957589 %
# [epoch 1, iterations   782] loss: 2.054 accuracy: 20.482000 %
# Training Done

# %% [markdown]
# # 5.2 Distributed Training with DeepSpeed
#
# The DeepSpeed library is a Deep Learning optimization library for distributed training on several different hardware sizes ranging from a single GPU to low-end clusters, going up to massive supercomputers.
#
# <img src="https://www.deepspeed.ai/assets/images/3d-parallelism.png" width="650" />
#
#
# - Distributed Training with Mixed Precision on Single-GPU/Multi-GPU/Multi-Node
# - Pipeline Parallelism and an integration with Megatron-LM tensor parallel
# - Zero Redundancy Optimizer (ZeRO): Memory optimization techniques
# - ZeRO-Offload: Offloading data and compute to the CPU
# - Mixture of Experts (MoE)

# %% [markdown]
# ## 5.2.1 Make the code run with DeepSpeed
#
# The DeepSpeed engine can wrap neural networks defined as `torch.nn.module`. To write the previous Model with DeepSpeed, we will need to:
#
# - Instantiate the DeepSpeed Model engine and optimizer: Use the DeepSpeed initializer as follows:
# `model_engine, optimizer= deepspeed.initialize(args=args, model=Your_Network, model_parameters=parameters, training_data=trainset)`
# - The variable `args` should embed training arguments and the DeepSpeed arguments. We can use `deepspeed.add_config_arguments(parser)` to add the DeepSpeed arguments to our parser.
# - Refer to the deepspeed `model_engine` instead of `Your_Network` in the rest of the code.
# - For distributed training implementation with `torch.distributed.init_process_group(...)`, replace that with `deepspeed.init_distributed()`
#
# Learn more on how to write DeepSpeed models with the [dedicated DeepSpeed documentation.](https://www.deepspeed.ai/getting-started/#writing-deepspeed-models)
#
# DeepSpeed arguments can be passed throughout a JSON configuration file. Let's have a look at our the DeepSpeed configuration file:

# %%
# Have a look at the DeepSpeed config
# !cat code/moe/ds_config.json
# Out:
# {
#   "train_batch_size": 16,
#   "steps_per_print": 2000,
#   "optimizer": {
#     "type": "Adam",
#     "params": {
#       "lr": 0.001,
#       "betas": [
#         0.8,
#         0.999
#       ],
#       "eps": 1e-8,
#       "weight_decay": 3e-7
#     }
#   },
#   "scheduler": {
#     "type": "WarmupLR",
#     "params": {
#       "warmup_min_lr": 0,
#       "warmup_max_lr": 0.001,
#       "warmup_num_steps": 1000
#     }
#   },
#   "gradient_clipping": 1.0,
#   "prescale_gradients": false,
#   "fp16": {
#       "enabled": true,
#       "fp16_master_weights_and_grads": false,
#       "loss_scale": 0,
#       "loss_scale_window": 500,
#       "hysteresis": 2,
#       "min_loss_scale": 1,
#       "initial_scale_power": 15
#   },
#   "wall_clock_breakdown": false,
#   "zero_optimization": {
#       "stage": 0,
#       "allgather_partitions": true,
#       "reduce_scatter": true,
#       "allgather_bucket_size": 50000000,
#       "reduce_bucket_size": 50000000,
#       "overlap_comm": true,
#       "contiguous_gradients": true,
#       "cpu_offload": false
#   }
#
# }

# %%
# import the relevant library
import deepspeed

# define the argument class, the training arguments, and DeepSpeed
class Args:
    log_interval=100 
    batch_size=64
    epochs=2
    deepspeed = True
    deepspeed_config = "code/moe/ds_config.json"
    local_rank= 0

args=Args()

# %%
# define the CNN network
cnn_net_ds = CNN_Net()

# Define the hyperparameters
parameters = filter(lambda p: p.requires_grad, cnn_net_ds.parameters())

# Wrap the CNN network with DeepSpeed
model_engine, optimizer, _, _ = deepspeed.initialize(args=args, model=cnn_net_ds, model_parameters=parameters, training_data=trainset)

# enable mixed precision
fp16 = model_engine.fp16_enabled()

device = model_engine.local_rank
criterion = nn.CrossEntropyLoss()

# Tensorboard event recording directory 
writer_ds = SummaryWriter('megatron/tensorboard/cifar10_DS')
# Out:
# [2023-07-27 08:40:27,195] [INFO] [logging.py:69:log_dist] [Rank -1] DeepSpeed info: version=0.6.5, git-hash=unknown, git-branch=unknown
# [2023-07-27 08:40:27,196] [INFO] [distributed.py:36:init_distributed] Not using the DeepSpeed or torch.distributed launchers, attempting to detect MPI environment...
# [2023-07-27 08:40:27,409] [INFO] [distributed.py:85:mpi_discovery] Discovered MPI settings of world_rank=0, local_rank=0, world_size=1, master_addr=172.18.0.5, master_port=29500
# [2023-07-27 08:40:27,410] [INFO] [distributed.py:48:init_distributed] Initializing torch distributed with backend: nccl
# [2023-07-27 08:40:27,681] [INFO] [engine.py:278:__init__] DeepSpeed Flops Profiler Enabled: False
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# Creating extension directory /home/admin/.cache/torch_extensions/py38_cu115/fused_adam...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/admin/.cache/torch_extensions/py38_cu115/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/3] /usr/local/cuda/bin/nvcc  -DTORCH_EXTENSION_NAME=fused_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1013\" -I/opt/conda/lib/python3.8/site-packages/deepspeed/ops/csrc/includes -I/opt/conda/lib/python3.8/site-packages/deepspeed/ops/csrc/adam -isystem /opt/conda/lib/python3.8/site-packages/torch/include -isystem /opt/conda/lib/python3.8/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.8/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.8/site-packages/torch/include/THC -isystem /usr/local/cuda/include -isystem /opt/conda/include/python3.8 -D_GLIBCXX_USE_CXX11_ABI=1 -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -gencode=arch=compute_80,code=compute_80 -gencode=arch=compute_80,code=sm_80 --compiler-options '-fPIC' -O3 -DVERSION_GE_1_1 -DVERSION_GE_1_3 -DVERSION_GE_1_5 -lineinfo --use_fast_math -gencode=arch=compute_80,code=sm_80 -gencode=arch=compute_80,code=compute_80 -std=c++14 -c /opt/conda/lib/python3.8/site-packages/deepspeed/ops/csrc/adam/multi_tensor_adam.cu -o multi_tensor_adam.cuda.o
# [2/3] c++ -MMD -MF fused_adam_frontend.o.d -DTORCH_EXTENSION_NAME=fused_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1013\" -I/opt/conda/lib/python3.8/site-packages/deepspeed/ops/csrc/includes -I/opt/conda/lib/python3.8/site-packages/deepspeed/ops/csrc/adam -isystem /opt/conda/lib/python3.8/site-packages/torch/include -isystem /opt/conda/lib/python3.8/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.8/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.8/site-packages/torch/include/THC -isystem /usr/local/cuda/include -isystem /opt/conda/include/python3.8 -D_GLIBCXX_USE_CXX11_ABI=1 -fPIC -std=c++14 -O3 -std=c++14 -g -Wno-reorder -DVERSION_GE_1_1 -DVERSION_GE_1_3 -DVERSION_GE_1_5 -c /opt/conda/lib/python3.8/site-packages/deepspeed/ops/csrc/adam/fused_adam_frontend.cpp -o fused_adam_frontend.o
# [3/3] c++ fused_adam_frontend.o multi_tensor_adam.cuda.o -shared -L/opt/conda/lib/python3.8/site-packages/torch/lib -lc10 -lc10_cuda -ltorch_cpu -ltorch_cuda -ltorch -ltorch_python -L/usr/local/cuda/lib64 -lcudart -o fused_adam.so
# Loading extension module fused_adam...
# Time to load fused_adam op: 17.83674454689026 seconds
# [2023-07-27 08:40:46,061] [INFO] [engine.py:1100:_configure_optimizer] Using DeepSpeed Optimizer param name adam as basic optimizer
# [2023-07-27 08:40:46,061] [INFO] [engine.py:1108:_configure_optimizer] DeepSpeed Basic Optimizer = FusedAdam
# [2023-07-27 08:40:46,062] [INFO] [logging.py:69:log_dist] [Rank 0] Creating fp16 optimizer with dynamic loss scale
# [2023-07-27 08:40:46,063] [INFO] [logging.py:69:log_dist] [Rank 0] DeepSpeed Final Optimizer = adam
# [2023-07-27 08:40:46,064] [INFO] [engine.py:785:_configure_lr_scheduler] DeepSpeed using configured LR scheduler = WarmupLR
# [2023-07-27 08:40:46,064] [INFO] [logging.py:69:log_dist] [Rank 0] DeepSpeed LR Scheduler = <deepspeed.runtime.lr_schedules.WarmupLR object at 0x7ef6bee1e370>
# [2023-07-27 08:40:46,065] [INFO] [logging.py:69:log_dist] [Rank 0] step=0, skipped=0, lr=[0.001], mom=[[0.8, 0.999]]
# [2023-07-27 08:40:46,065] [INFO] [config.py:1059:print] DeepSpeedEngine configuration:
# [2023-07-27 08:40:46,065] [INFO] [config.py:1063:print]   activation_checkpointing_config  {
#     "partition_activations": false,
#     "contiguous_memory_optimization": false,
#     "cpu_checkpointing": false,
#     "number_checkpoints": null,
#     "synchronize_checkpoint_boundary": false,
#     "profile": false
# }
# [2023-07-27 08:40:46,066] [INFO] [config.py:1063:print]   aio_config ................... {'block_size': 1048576, 'queue_depth': 8, 'thread_count': 1, 'single_submit': False, 'overlap_events': True}
# [2023-07-27 08:40:46,066] [INFO] [config.py:1063:print]   amp_enabled .................. False
# [2023-07-27 08:40:46,067] [INFO] [config.py:1063:print]   amp_params ................... False
# [2023-07-27 08:40:46,067] [INFO] [config.py:1063:print]   autotuning_config ............ {
#     "enabled": false,
#     "start_step": null,
#     "end_step": null,
#     "metric_path": null,
#     "arg_mappings": null,
#     "metric": "throughput",
#     "model_info": null,
#     "results_dir": null,
#     "exps_dir": null,
#     "overwrite": true,
#     "fast": true,
#     "start_profile_step": 3,
#     "end_profile_step": 5,
#     "tuner_type": "gridsearch",
#     "tuner_early_stopping": 5,
#     "tuner_num_trials": 50,
#     "model_info_path": null,
#     "mp_size": 1,
#     "max_train_batch_size": null,
#     "min_train_batch_size": 1,
#     "max_train_micro_batch_size_per_gpu": 1.024000e+03,
#     "min_train_micro_batch_size_per_gpu": 1,
#     "num_tuning_micro_batch_sizes": 3
# }
# [2023-07-27 08:40:46,068] [INFO] [config.py:1063:print]   bfloat16_enabled ............. False
# [2023-07-27 08:40:46,068] [INFO] [config.py:1063:print]   checkpoint_tag_validation_enabled  True
# [2023-07-27 08:40:46,068] [INFO] [config.py:1063:print]   checkpoint_tag_validation_fail  False
# [2023-07-27 08:40:46,069] [INFO] [config.py:1063:print]   communication_data_type ...... None
# [2023-07-27 08:40:46,069] [INFO] [config.py:1063:print]   curriculum_enabled ........... False
# [2023-07-27 08:40:46,069] [INFO] [config.py:1063:print]   curriculum_params ............ False
# [2023-07-27 08:40:46,070] [INFO] [config.py:1063:print]   dataloader_drop_last ......... False
# [2023-07-27 08:40:46,070] [INFO] [config.py:1063:print]   disable_allgather ............ False
# [2023-07-27 08:40:46,070] [INFO] [config.py:1063:print]   dump_state ................... False
# [2023-07-27 08:40:46,070] [INFO] [config.py:1063:print]   dynamic_loss_scale_args ...... {'init_scale': 32768, 'scale_window': 500, 'delayed_shift': 2, 'min_scale': 1}
# [2023-07-27 08:40:46,071] [INFO] [config.py:1063:print]   eigenvalue_enabled ........... False
# [2023-07-27 08:40:46,071] [INFO] [config.py:1063:print]   eigenvalue_gas_boundary_resolution  1
# [2023-07-27 08:40:46,071] [INFO] [config.py:1063:print]   eigenvalue_layer_name ........ bert.encoder.layer
# [2023-07-27 08:40:46,072] [INFO] [config.py:1063:print]   eigenvalue_layer_num ......... 0
# [2023-07-27 08:40:46,072] [INFO] [config.py:1063:print]   eigenvalue_max_iter .......... 100
# [2023-07-27 08:40:46,072] [INFO] [config.py:1063:print]   eigenvalue_stability ......... 1e-06
# [2023-07-27 08:40:46,072] [INFO] [config.py:1063:print]   eigenvalue_tol ............... 0.01
# [2023-07-27 08:40:46,073] [INFO] [config.py:1063:print]   eigenvalue_verbose ........... False
# [2023-07-27 08:40:46,073] [INFO] [config.py:1063:print]   elasticity_enabled ........... False
# [2023-07-27 08:40:46,073] [INFO] [config.py:1063:print]   flops_profiler_config ........ {
#     "enabled": false,
#     "profile_step": 1,
#     "module_depth": -1,
#     "top_modules": 1,
#     "detailed": true,
#     "output_file": null
# }
# [2023-07-27 08:40:46,074] [INFO] [config.py:1063:print]   fp16_enabled ................. True
# [2023-07-27 08:40:46,074] [INFO] [config.py:1063:print]   fp16_master_weights_and_gradients  False
# [2023-07-27 08:40:46,074] [INFO] [config.py:1063:print]   fp16_mixed_quantize .......... False
# [2023-07-27 08:40:46,074] [INFO] [config.py:1063:print]   global_rank .................. 0
# [2023-07-27 08:40:46,075] [INFO] [config.py:1063:print]   gradient_accumulation_steps .. 1
# [2023-07-27 08:40:46,075] [INFO] [config.py:1063:print]   gradient_clipping ............ 1.0
# [2023-07-27 08:40:46,075] [INFO] [config.py:1063:print]   gradient_predivide_factor .... 1.0
# [2023-07-27 08:40:46,075] [INFO] [config.py:1063:print]   initial_dynamic_scale ........ 32768
# [2023-07-27 08:40:46,076] [INFO] [config.py:1063:print]   loss_scale ................... 0
# [2023-07-27 08:40:46,076] [INFO] [config.py:1063:print]   memory_breakdown ............. False
# [2023-07-27 08:40:46,077] [INFO] [config.py:1063:print]   optimizer_legacy_fusion ...... False
# [2023-07-27 08:40:46,078] [INFO] [config.py:1063:print]   optimizer_name ............... adam
# [2023-07-27 08:40:46,078] [INFO] [config.py:1063:print]   optimizer_params ............. {'lr': 0.001, 'betas': [0.8, 0.999], 'eps': 1e-08, 'weight_decay': 3e-07}
# [2023-07-27 08:40:46,078] [INFO] [config.py:1063:print]   pipeline ..................... {'stages': 'auto', 'partition': 'best', 'seed_layers': False, 'activation_checkpoint_interval': 0}
# [2023-07-27 08:40:46,078] [INFO] [config.py:1063:print]   pld_enabled .................. False
# [2023-07-27 08:40:46,079] [INFO] [config.py:1063:print]   pld_params ................... False
# [2023-07-27 08:40:46,079] [INFO] [config.py:1063:print]   prescale_gradients ........... False
# [2023-07-27 08:40:46,079] [INFO] [config.py:1063:print]   quantize_change_rate ......... 0.001
# [2023-07-27 08:40:46,080] [INFO] [config.py:1063:print]   quantize_groups .............. 1
# [2023-07-27 08:40:46,080] [INFO] [config.py:1063:print]   quantize_offset .............. 1000
# [2023-07-27 08:40:46,080] [INFO] [config.py:1063:print]   quantize_period .............. 1000
# [2023-07-27 08:40:46,081] [INFO] [config.py:1063:print]   quantize_rounding ............ 0
# [2023-07-27 08:40:46,081] [INFO] [config.py:1063:print]   quantize_start_bits .......... 16
# [2023-07-27 08:40:46,081] [INFO] [config.py:1063:print]   quantize_target_bits ......... 8
# [2023-07-27 08:40:46,082] [INFO] [config.py:1063:print]   quantize_training_enabled .... False
# [2023-07-27 08:40:46,082] [INFO] [config.py:1063:print]   quantize_type ................ 0
# [2023-07-27 08:40:46,082] [INFO] [config.py:1063:print]   quantize_verbose ............. False
# [2023-07-27 08:40:46,083] [INFO] [config.py:1063:print]   scheduler_name ............... WarmupLR
# [2023-07-27 08:40:46,084] [INFO] [config.py:1063:print]   scheduler_params ............. {'warmup_min_lr': 0, 'warmup_max_lr': 0.001, 'warmup_num_steps': 1000}
# [2023-07-27 08:40:46,084] [INFO] [config.py:1063:print]   sparse_attention ............. None
# [2023-07-27 08:40:46,084] [INFO] [config.py:1063:print]   sparse_gradients_enabled ..... False
# [2023-07-27 08:40:46,084] [INFO] [config.py:1063:print]   steps_per_print .............. 2000
# [2023-07-27 08:40:46,085] [INFO] [config.py:1063:print]   tensorboard_enabled .......... False
# [2023-07-27 08:40:46,085] [INFO] [config.py:1063:print]   tensorboard_job_name ......... DeepSpeedJobName
# [2023-07-27 08:40:46,085] [INFO] [config.py:1063:print]   tensorboard_output_path ......
# [2023-07-27 08:40:46,085] [INFO] [config.py:1063:print]   train_batch_size ............. 16
# [2023-07-27 08:40:46,086] [INFO] [config.py:1063:print]   train_micro_batch_size_per_gpu  16
# [2023-07-27 08:40:46,086] [INFO] [config.py:1063:print]   use_quantizer_kernel ......... False
# [2023-07-27 08:40:46,086] [INFO] [config.py:1063:print]   wall_clock_breakdown ......... False
# [2023-07-27 08:40:46,087] [INFO] [config.py:1063:print]   world_size ................... 1
# [2023-07-27 08:40:46,087] [INFO] [config.py:1063:print]   zero_allow_untested_optimizer  False
# [2023-07-27 08:40:46,088] [INFO] [config.py:1063:print]   zero_config .................. {
#     "stage": 0,
#     "contiguous_gradients": true,
#     "reduce_scatter": true,
#     "reduce_bucket_size": 5.000000e+07,
#     "allgather_partitions": true,
#     "allgather_bucket_size": 5.000000e+07,
#     "overlap_comm": true,
#     "load_from_fp32_weights": true,
#     "elastic_checkpoint": false,
#     "offload_param": null,
#     "offload_optimizer": null,
#     "sub_group_size": 1.000000e+09,
#     "prefetch_bucket_size": 5.000000e+07,
#     "param_persistence_threshold": 1.000000e+05,
#     "max_live_parameters": 1.000000e+09,
#     "max_reuse_distance": 1.000000e+09,
#     "gather_16bit_weights_on_model_save": false,
#     "ignore_unused_parameters": true,
#     "round_robin_gradients": false,
#     "legacy_stage1": false
# }
# [2023-07-27 08:40:46,088] [INFO] [config.py:1063:print]   zero_enabled ................. False
# [2023-07-27 08:40:46,088] [INFO] [config.py:1063:print]   zero_optimization_stage ...... 0
# [2023-07-27 08:40:46,089] [INFO] [config.py:1065:print]   json = {
#     "train_batch_size": 16,
#     "steps_per_print": 2.000000e+03,
#     "optimizer": {
#         "type": "Adam",
#         "params": {
#             "lr": 0.001,
#             "betas": [0.8, 0.999],
#             "eps": 1e-08,
#             "weight_decay": 3e-07
#         }
#     },
#     "scheduler": {
#         "type": "WarmupLR",
#         "params": {
#             "warmup_min_lr": 0,
#             "warmup_max_lr": 0.001,
#             "warmup_num_steps": 1000
#         }
#     },
#     "gradient_clipping": 1.0,
#     "prescale_gradients": false,
#     "fp16": {
#         "enabled": true,
#         "fp16_master_weights_and_grads": false,
#         "loss_scale": 0,
#         "loss_scale_window": 500,
#         "hysteresis": 2,
#         "min_loss_scale": 1,
#         "initial_scale_power": 15
#     },
#     "wall_clock_breakdown": false,
#     "zero_optimization": {
#         "stage": 0,
#         "allgather_partitions": true,
#         "reduce_scatter": true,
#         "allgather_bucket_size": 5.000000e+07,
#         "reduce_bucket_size": 5.000000e+07,
#         "overlap_comm": true,
#         "contiguous_gradients": true,
#         "cpu_offload": false
#     }
# }
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# Creating extension directory /home/admin/.cache/torch_extensions/py38_cu115/utils...
# Emitting ninja build file /home/admin/.cache/torch_extensions/py38_cu115/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/2] c++ -MMD -MF flatten_unflatten.o.d -DTORCH_EXTENSION_NAME=utils -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1013\" -isystem /opt/conda/lib/python3.8/site-packages/torch/include -isystem /opt/conda/lib/python3.8/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.8/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.8/site-packages/torch/include/THC -isystem /opt/conda/include/python3.8 -D_GLIBCXX_USE_CXX11_ABI=1 -fPIC -std=c++14 -c /opt/conda/lib/python3.8/site-packages/deepspeed/ops/csrc/utils/flatten_unflatten.cpp -o flatten_unflatten.o
# [2/2] c++ flatten_unflatten.o -shared -L/opt/conda/lib/python3.8/site-packages/torch/lib -lc10 -ltorch_cpu -ltorch -ltorch_python -o utils.so
# Loading extension module utils...
# Time to load utils op: 9.604309558868408 seconds

# %%
# Train the CNN with DeepSpeed
for epoch in range(epochs): 
    running_loss = 0.0
    correct = 0
    total = 0
    for i, data in enumerate(trainloader):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data[0].to(device), data[1].to(device)
        if fp16:
            inputs = inputs.half()        
        # zero the parameter gradients
        optimizer.zero_grad()
        
        # Forward pass
        outputs = model_engine(inputs)             # Changed net_cnn to model_engine
        loss = criterion(outputs, labels)
        
        # Backward pass
        model_engine.backward(loss)                # Changed net_cnn to model_engine
        model_engine.step()                        # Changed net_cnn to model_engine
        
        # print the loss and accuracy metrics log_interval mini-batches
        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        if i % log_interval == (log_interval - 1):  
            print('[epoch %d, iterations %5d] loss: %.3f accuracy: %2f %%' %  (epoch , i + 1, running_loss / log_interval, 100.*correct/total))
            writer_ds.add_scalar("Training Cross Entropy Loss", running_loss / log_interval, i + 1)
            writer_ds.add_scalar("Training Accuracy", 100.*correct/total, i + 1)
            running_loss = 0.0
            
    # print the last iterations 
    print('[epoch %d, iterations %5d] loss: %.3f accuracy: %2f %%' %  (epoch , i + 1, running_loss / ((i % log_interval) + 1), 100.*correct/total))
    writer.add_scalar("Training Cross Entropy Loss", running_loss / ((i % log_interval) + 1), i + 1)
    writer.add_scalar("Training Accuracy", 100.*correct/total, i + 1)
    
print('Training Done')
writer_ds.add_graph(model_engine, inputs)
writer_ds.flush()
writer_ds.close()
# Out:
# [epoch 0, iterations   100] loss: 2.077 accuracy: 22.265625 %
# [epoch 0, iterations   200] loss: 1.795 accuracy: 28.015625 %
# [epoch 0, iterations   300] loss: 1.707 accuracy: 31.302083 %
# [epoch 0, iterations   400] loss: 1.611 accuracy: 33.738281 %
# [epoch 0, iterations   500] loss: 1.583 accuracy: 35.350000 %
# [2023-07-27 08:41:22,354] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:41:22,355] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 32768 to 65536
# [2023-07-27 08:41:22,360] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 501
# [2023-07-27 08:41:22,360] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 65536 to 32768.0
# [2023-07-27 08:41:22,361] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 65536, reducing to 32768.0
# [epoch 0, iterations   600] loss: 1.563 accuracy: 36.653646 %
# [epoch 0, iterations   700] loss: 1.502 accuracy: 37.799107 %
# [epoch 0, iterations   782] loss: 1.492 accuracy: 38.678000 %
# [epoch 1, iterations   100] loss: 1.438 accuracy: 47.546875 %
# [epoch 1, iterations   200] loss: 1.423 accuracy: 48.054688 %
# [2023-07-27 08:41:25,000] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:41:25,001] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 32768.0 to 65536.0
# [2023-07-27 08:41:25,007] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 1003
# [2023-07-27 08:41:25,008] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 65536.0 to 32768.0
# [2023-07-27 08:41:25,008] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 65536.0, reducing to 32768.0
# [epoch 1, iterations   300] loss: 1.410 accuracy: 48.281250 %
# [epoch 1, iterations   400] loss: 1.393 accuracy: 48.851562 %
# [epoch 1, iterations   500] loss: 1.381 accuracy: 49.096875 %
# [epoch 1, iterations   600] loss: 1.361 accuracy: 49.281250 %
# [epoch 1, iterations   700] loss: 1.329 accuracy: 49.700893 %
# [2023-07-27 08:41:27,374] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:41:27,375] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 32768.0 to 65536.0
# [2023-07-27 08:41:27,386] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 1505
# [2023-07-27 08:41:27,386] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 65536.0 to 32768.0
# [2023-07-27 08:41:27,387] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 65536.0, reducing to 32768.0
# [epoch 1, iterations   782] loss: 1.327 accuracy: 49.920000 %
# Training Done

# %% [markdown]
# The previous steps are aggregated into the python script [cifar10_deepspeed.py](./code/moe/cifar10_deepspeed.py).

# %% [markdown]
# ## 5.2.2 Scale-out training with Data Parallelism
#
# Let's now scale our previous training using distributed training techniques. To run the previous code on 4 GPUs using Data Parallel Distribution, instead of using torch.distributed.launch command, we can use deepspeed implementation.
#
# `python -m torch.distributed.launch --nproc_per_node=4 my_code.py <args>`
#
# With DeepSpeed, simply replace torch.distributed.launch with deepspeed and add a new argument --deepspeed ds_config.json
#
# `deepspeed --num_gpus=4 my_code.py  <args> --deepspeed ds_config.json`
#
# Execute the next cell to run the previous cifar10_deepspeed.py training code on 4 GPUs with DeepSpeed:

# %%
# Kill zombie processes
import IPython
IPython.Application.instance().kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}

# %%
# run the training on 4 GPUs with Data parallel
# !deepspeed --num_gpus=4 /dli/code/moe/cifar10_deepspeed.py \
    --deepspeed \
    --deepspeed_config /dli/code/moe/ds_config.json \
    --profile-execution=True \
    --profile-name='zero0'
# Out:
# [2023-07-27 08:43:09,795] [WARNING] [runner.py:159:fetch_hostfile] Unable to find hostfile, will proceed with training with local resources only.
# [2023-07-27 08:43:09,975] [INFO] [runner.py:457:main] cmd = /opt/conda/bin/python3.8 -u -m deepspeed.launcher.launch --world_info=eyJsb2NhbGhvc3QiOiBbMCwgMSwgMiwgM119 --master_addr=127.0.0.1 --master_port=29500 /dli/code/moe/cifar10_deepspeed.py --deepspeed --deepspeed_config /dli/code/moe/ds_config.json --profile-execution=True --profile-name=zero0
# [2023-07-27 08:43:10,988] [INFO] [launch.py:96:main] 0 NCCL_P2P_DISABLE=1
# [2023-07-27 08:43:10,989] [INFO] [launch.py:96:main] 0 NCCL_VERSION=2.11.4
# [2023-07-27 08:43:10,989] [INFO] [launch.py:103:main] WORLD INFO DICT: {'localhost': [0, 1, 2, 3]}
# [2023-07-27 08:43:10,989] [INFO] [launch.py:109:main] nnodes=1, num_local_procs=4, node_rank=0
# [2023-07-27 08:43:10,989] [INFO] [launch.py:122:main] global_rank_mapping=defaultdict(<class 'list'>, {'localhost': [0, 1, 2, 3]})
# [2023-07-27 08:43:10,989] [INFO] [launch.py:123:main] dist_world_size=4
# [2023-07-27 08:43:10,989] [INFO] [launch.py:125:main] Setting CUDA_VISIBLE_DEVICES=0,1,2,3
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# [2023-07-27 08:43:13,474] [INFO] [logging.py:69:log_dist] [Rank -1] DeepSpeed info: version=0.6.5, git-hash=unknown, git-branch=unknown
# [2023-07-27 08:43:13,475] [INFO] [distributed.py:48:init_distributed] Initializing torch distributed with backend: nccl
# [2023-07-27 08:43:13,495] [INFO] [logging.py:69:log_dist] [Rank -1] DeepSpeed info: version=0.6.5, git-hash=unknown, git-branch=unknown
# [2023-07-27 08:43:13,533] [INFO] [logging.py:69:log_dist] [Rank -1] DeepSpeed info: version=0.6.5, git-hash=unknown, git-branch=unknown
# [2023-07-27 08:43:13,533] [INFO] [logging.py:69:log_dist] [Rank -1] DeepSpeed info: version=0.6.5, git-hash=unknown, git-branch=unknown
# [2023-07-27 08:43:16,175] [INFO] [engine.py:278:__init__] DeepSpeed Flops Profiler Enabled: False
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/admin/.cache/torch_extensions/py38_cu115/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.1018378734588623 seconds
# [2023-07-27 08:43:16,762] [INFO] [engine.py:1100:_configure_optimizer] Using DeepSpeed Optimizer param name adam as basic optimizer
# [2023-07-27 08:43:16,762] [INFO] [engine.py:1108:_configure_optimizer] DeepSpeed Basic Optimizer = FusedAdam
# [2023-07-27 08:43:16,762] [INFO] [logging.py:69:log_dist] [Rank 0] Creating fp16 optimizer with dynamic loss scale
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10253334045410156 seconds
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.1023402214050293 seconds
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10217404365539551 seconds
# [2023-07-27 08:43:17,125] [INFO] [logging.py:69:log_dist] [Rank 0] DeepSpeed Final Optimizer = adam
# [2023-07-27 08:43:17,125] [INFO] [engine.py:785:_configure_lr_scheduler] DeepSpeed using configured LR scheduler = WarmupLR
# [2023-07-27 08:43:17,126] [INFO] [logging.py:69:log_dist] [Rank 0] DeepSpeed LR Scheduler = <deepspeed.runtime.lr_schedules.WarmupLR object at 0x7fed4197ce50>
# [2023-07-27 08:43:17,126] [INFO] [logging.py:69:log_dist] [Rank 0] step=0, skipped=0, lr=[0.001], mom=[[0.8, 0.999]]
# [2023-07-27 08:43:17,126] [INFO] [config.py:1059:print] DeepSpeedEngine configuration:
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# [2023-07-27 08:43:17,126] [INFO] [config.py:1063:print]   activation_checkpointing_config  {
#     "partition_activations": false,
#     "contiguous_memory_optimization": false,
#     "cpu_checkpointing": false,
#     "number_checkpoints": null,
#     "synchronize_checkpoint_boundary": false,
#     "profile": false
# }
# [2023-07-27 08:43:17,126] [INFO] [config.py:1063:print]   aio_config ................... {'block_size': 1048576, 'queue_depth': 8, 'thread_count': 1, 'single_submit': False, 'overlap_events': True}
# [2023-07-27 08:43:17,126] [INFO] [config.py:1063:print]   amp_enabled .................. False
# [2023-07-27 08:43:17,126] [INFO] [config.py:1063:print]   amp_params ................... False
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# [2023-07-27 08:43:17,126] [INFO] [config.py:1063:print]   autotuning_config ............ {
#     "enabled": false,
#     "start_step": null,
#     "end_step": null,
#     "metric_path": null,
#     "arg_mappings": null,
#     "metric": "throughput",
#     "model_info": null,
#     "results_dir": null,
#     "exps_dir": null,
#     "overwrite": true,
#     "fast": true,
#     "start_profile_step": 3,
#     "end_profile_step": 5,
#     "tuner_type": "gridsearch",
#     "tuner_early_stopping": 5,
#     "tuner_num_trials": 50,
#     "model_info_path": null,
#     "mp_size": 1,
#     "max_train_batch_size": null,
#     "min_train_batch_size": 1,
#     "max_train_micro_batch_size_per_gpu": 1.024000e+03,
#     "min_train_micro_batch_size_per_gpu": 1,
#     "num_tuning_micro_batch_sizes": 3
# }
# [2023-07-27 08:43:17,126] [INFO] [config.py:1063:print]   bfloat16_enabled ............. False
# [2023-07-27 08:43:17,126] [INFO] [config.py:1063:print]   checkpoint_tag_validation_enabled  True
# [2023-07-27 08:43:17,126] [INFO] [config.py:1063:print]   checkpoint_tag_validation_fail  False
# [2023-07-27 08:43:17,126] [INFO] [config.py:1063:print]   communication_data_type ...... None
# [2023-07-27 08:43:17,126] [INFO] [config.py:1063:print]   curriculum_enabled ........... False
# [2023-07-27 08:43:17,126] [INFO] [config.py:1063:print]   curriculum_params ............ False
# [2023-07-27 08:43:17,126] [INFO] [config.py:1063:print]   dataloader_drop_last ......... False
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   disable_allgather ............ False
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   dump_state ................... False
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   dynamic_loss_scale_args ...... {'init_scale': 32768, 'scale_window': 500, 'delayed_shift': 2, 'min_scale': 1}
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   eigenvalue_enabled ........... False
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   eigenvalue_gas_boundary_resolution  1
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   eigenvalue_layer_name ........ bert.encoder.layer
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   eigenvalue_layer_num ......... 0
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   eigenvalue_max_iter .......... 100
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   eigenvalue_stability ......... 1e-06
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   eigenvalue_tol ............... 0.01
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   eigenvalue_verbose ........... False
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   elasticity_enabled ........... False
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   flops_profiler_config ........ {
#     "enabled": false,
#     "profile_step": 1,
#     "module_depth": -1,
#     "top_modules": 1,
#     "detailed": true,
#     "output_file": null
# }
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   fp16_enabled ................. True
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   fp16_master_weights_and_gradients  False
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   fp16_mixed_quantize .......... False
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   global_rank .................. 0
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   gradient_accumulation_steps .. 1
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   gradient_clipping ............ 1.0
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   gradient_predivide_factor .... 1.0
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   initial_dynamic_scale ........ 32768
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   loss_scale ................... 0
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   memory_breakdown ............. False
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   optimizer_legacy_fusion ...... False
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   optimizer_name ............... adam
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   optimizer_params ............. {'lr': 0.001, 'betas': [0.8, 0.999], 'eps': 1e-08, 'weight_decay': 3e-07}
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   pipeline ..................... {'stages': 'auto', 'partition': 'best', 'seed_layers': False, 'activation_checkpoint_interval': 0}
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   pld_enabled .................. False
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   pld_params ................... False
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   prescale_gradients ........... False
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   quantize_change_rate ......... 0.001
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   quantize_groups .............. 1
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   quantize_offset .............. 1000
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   quantize_period .............. 1000
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   quantize_rounding ............ 0
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   quantize_start_bits .......... 16
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   quantize_target_bits ......... 8
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   quantize_training_enabled .... False
# [2023-07-27 08:43:17,127] [INFO] [config.py:1063:print]   quantize_type ................ 0
# [2023-07-27 08:43:17,128] [INFO] [config.py:1063:print]   quantize_verbose ............. False
# [2023-07-27 08:43:17,128] [INFO] [config.py:1063:print]   scheduler_name ............... WarmupLR
# [2023-07-27 08:43:17,128] [INFO] [config.py:1063:print]   scheduler_params ............. {'warmup_min_lr': 0, 'warmup_max_lr': 0.001, 'warmup_num_steps': 1000}
# [2023-07-27 08:43:17,128] [INFO] [config.py:1063:print]   sparse_attention ............. None
# [2023-07-27 08:43:17,128] [INFO] [config.py:1063:print]   sparse_gradients_enabled ..... False
# [2023-07-27 08:43:17,128] [INFO] [config.py:1063:print]   steps_per_print .............. 2000
# [2023-07-27 08:43:17,128] [INFO] [config.py:1063:print]   tensorboard_enabled .......... False
# [2023-07-27 08:43:17,128] [INFO] [config.py:1063:print]   tensorboard_job_name ......... DeepSpeedJobName
# [2023-07-27 08:43:17,128] [INFO] [config.py:1063:print]   tensorboard_output_path ......
# [2023-07-27 08:43:17,128] [INFO] [config.py:1063:print]   train_batch_size ............. 16
# [2023-07-27 08:43:17,128] [INFO] [config.py:1063:print]   train_micro_batch_size_per_gpu  4
# [2023-07-27 08:43:17,128] [INFO] [config.py:1063:print]   use_quantizer_kernel ......... False
# [2023-07-27 08:43:17,128] [INFO] [config.py:1063:print]   wall_clock_breakdown ......... False
# [2023-07-27 08:43:17,128] [INFO] [config.py:1063:print]   world_size ................... 4
# [2023-07-27 08:43:17,128] [INFO] [config.py:1063:print]   zero_allow_untested_optimizer  False
# [2023-07-27 08:43:17,128] [INFO] [config.py:1063:print]   zero_config .................. {
#     "stage": 0,
#     "contiguous_gradients": true,
#     "reduce_scatter": true,
#     "reduce_bucket_size": 5.000000e+07,
#     "allgather_partitions": true,
#     "allgather_bucket_size": 5.000000e+07,
#     "overlap_comm": true,
#     "load_from_fp32_weights": true,
#     "elastic_checkpoint": false,
#     "offload_param": null,
#     "offload_optimizer": null,
#     "sub_group_size": 1.000000e+09,
#     "prefetch_bucket_size": 5.000000e+07,
#     "param_persistence_threshold": 1.000000e+05,
#     "max_live_parameters": 1.000000e+09,
#     "max_reuse_distance": 1.000000e+09,
#     "gather_16bit_weights_on_model_save": false,
#     "ignore_unused_parameters": true,
#     "round_robin_gradients": false,
#     "legacy_stage1": false
# }
# [2023-07-27 08:43:17,128] [INFO] [config.py:1063:print]   zero_enabled ................. False
# [2023-07-27 08:43:17,128] [INFO] [config.py:1063:print]   zero_optimization_stage ...... 0
# [2023-07-27 08:43:17,128] [INFO] [config.py:1065:print]   json = {
#     "train_batch_size": 16,
#     "steps_per_print": 2.000000e+03,
#     "optimizer": {
#         "type": "Adam",
#         "params": {
#             "lr": 0.001,
#             "betas": [0.8, 0.999],
#             "eps": 1e-08,
#             "weight_decay": 3e-07
#         }
#     },
#     "scheduler": {
#         "type": "WarmupLR",
#         "params": {
#             "warmup_min_lr": 0,
#             "warmup_max_lr": 0.001,
#             "warmup_num_steps": 1000
#         }
#     },
#     "gradient_clipping": 1.0,
#     "prescale_gradients": false,
#     "fp16": {
#         "enabled": true,
#         "fp16_master_weights_and_grads": false,
#         "loss_scale": 0,
#         "loss_scale_window": 500,
#         "hysteresis": 2,
#         "min_loss_scale": 1,
#         "initial_scale_power": 15
#     },
#     "wall_clock_breakdown": false,
#     "zero_optimization": {
#         "stage": 0,
#         "allgather_partitions": true,
#         "reduce_scatter": true,
#         "allgather_bucket_size": 5.000000e+07,
#         "reduce_bucket_size": 5.000000e+07,
#         "overlap_comm": true,
#         "contiguous_gradients": true,
#         "cpu_offload": false
#     }
# }
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# Emitting ninja build file /home/admin/.cache/torch_extensions/py38_cu115/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ninja: no work to do.
# Loading extension module utils...
# Time to load utils op: 0.10494685173034668 seconds
# Loading extension module utils...
# Loading extension module utils...
# Time to load utils op: 0.20225167274475098 seconds
# Time to load utils op: 0.20227742195129395 seconds
# Loading extension module utils...
# Time to load utils op: 0.20238852500915527 seconds
# [epoch 0, iterations   100] loss: 2.184 accuracy: 18.250000 %[epoch 0, iterations   100] loss: 2.182 accuracy: 19.000000 %
#
# [epoch 0, iterations   100] loss: 2.222 accuracy: 12.500000 %
# [epoch 0, iterations   100] loss: 2.219 accuracy: 18.000000 %
# [2023-07-27 08:43:20,473] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 110
# [2023-07-27 08:43:20,474] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 32768 to 16384.0
# [2023-07-27 08:43:20,473] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 110
# [2023-07-27 08:43:20,474] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 32768 to 16384.0
# [2023-07-27 08:43:20,473] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 110
# [2023-07-27 08:43:20,474] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 32768 to 16384.0
# [2023-07-27 08:43:20,474] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 110
# [2023-07-27 08:43:20,474] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 32768 to 16384.0
# [2023-07-27 08:43:20,474] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 32768, reducing to 16384.0
# [2023-07-27 08:43:20,705] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 164
# [2023-07-27 08:43:20,705] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 164
# [2023-07-27 08:43:20,705] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 164
# [2023-07-27 08:43:20,705] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 16384.0 to 8192.0
# [2023-07-27 08:43:20,705] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 16384.0 to 8192.0
# [2023-07-27 08:43:20,705] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 16384.0 to 8192.0
# [2023-07-27 08:43:20,705] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 164
# [2023-07-27 08:43:20,705] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 16384.0 to 8192.0
# [2023-07-27 08:43:20,705] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 16384.0, reducing to 8192.0
# [epoch 0, iterations   200] loss: 2.073 accuracy: 20.500000 %[epoch 0, iterations   200] loss: 2.012 accuracy: 21.625000 %
# [epoch 0, iterations   200] loss: 1.997 accuracy: 20.250000 %
#
# [epoch 0, iterations   200] loss: 2.015 accuracy: 23.500000 %
# [epoch 0, iterations   300] loss: 1.963 accuracy: 22.083333 %[epoch 0, iterations   300] loss: 1.952 accuracy: 21.750000 %[epoch 0, iterations   300] loss: 1.973 accuracy: 23.000000 %
#
#
# [epoch 0, iterations   300] loss: 1.930 accuracy: 25.416667 %
# [epoch 0, iterations   400] loss: 1.859 accuracy: 24.250000 %[epoch 0, iterations   400] loss: 1.861 accuracy: 25.500000 %
# [epoch 0, iterations   400] loss: 1.889 accuracy: 22.562500 %
#
# [epoch 0, iterations   400] loss: 1.924 accuracy: 26.000000 %
# [epoch 0, iterations   500] loss: 1.887 accuracy: 25.200000 %[epoch 0, iterations   500] loss: 1.804 accuracy: 26.700000 %[epoch 0, iterations   500] loss: 1.726 accuracy: 25.150000 %
#
#
# [epoch 0, iterations   500] loss: 1.769 accuracy: 27.950000 %
# [epoch 0, iterations   600] loss: 1.791 accuracy: 27.750000 %[epoch 0, iterations   600] loss: 1.753 accuracy: 26.708333 %
#
# [epoch 0, iterations   600] loss: 1.746 accuracy: 26.708333 %
# [epoch 0, iterations   600] loss: 1.746 accuracy: 29.000000 %
# [2023-07-27 08:43:22,899] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:22,899] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:22,899] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:22,899] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 8192.0 to 16384.0
# [2023-07-27 08:43:22,899] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 8192.0 to 16384.0
# [2023-07-27 08:43:22,899] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 8192.0 to 16384.0
# [2023-07-27 08:43:22,900] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:22,900] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 8192.0 to 16384.0
# [2023-07-27 08:43:22,912] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 668
# [2023-07-27 08:43:22,912] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 668
# [2023-07-27 08:43:22,912] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 668
# [2023-07-27 08:43:22,912] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 16384.0 to 8192.0
# [2023-07-27 08:43:22,912] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 16384.0 to 8192.0
# [2023-07-27 08:43:22,912] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 16384.0 to 8192.0
# [2023-07-27 08:43:22,913] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 668
# [2023-07-27 08:43:22,913] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 16384.0 to 8192.0
# [2023-07-27 08:43:22,913] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 16384.0, reducing to 8192.0
# [epoch 0, iterations   700] loss: 1.693 accuracy: 29.357143 %
# [epoch 0, iterations   700] loss: 1.650 accuracy: 29.214286 %[epoch 0, iterations   700] loss: 1.711 accuracy: 28.535714 %
#
# [epoch 0, iterations   700] loss: 1.771 accuracy: 29.785714 %
# [epoch 0, iterations   800] loss: 1.601 accuracy: 31.187500 %[epoch 0, iterations   800] loss: 1.636 accuracy: 30.156250 %
#
# [epoch 0, iterations   800] loss: 1.762 accuracy: 29.875000 %
# [epoch 0, iterations   800] loss: 1.684 accuracy: 30.687500 %
# [2023-07-27 08:43:23,829] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 877
# [2023-07-27 08:43:23,829] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 877
# [2023-07-27 08:43:23,829] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 877
# [2023-07-27 08:43:23,829] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:23,829] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:23,829] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:23,830] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 877
# [2023-07-27 08:43:23,830] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:23,830] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 8192.0, reducing to 4096.0
# [epoch 0, iterations   900] loss: 1.674 accuracy: 32.027778 %
# [epoch 0, iterations   900] loss: 1.704 accuracy: 30.416667 %
# [epoch 0, iterations   900] loss: 1.724 accuracy: 30.833333 %
# [epoch 0, iterations   900] loss: 1.676 accuracy: 31.472222 %
# [epoch 0, iterations  1000] loss: 1.676 accuracy: 32.650000 %[epoch 0, iterations  1000] loss: 1.626 accuracy: 31.225000 %
# [epoch 0, iterations  1000] loss: 1.620 accuracy: 31.775000 %
#
# [epoch 0, iterations  1000] loss: 1.600 accuracy: 32.775000 %
# [epoch 0, iterations  1100] loss: 1.607 accuracy: 33.340909 %[epoch 0, iterations  1100] loss: 1.648 accuracy: 31.931818 %[epoch 0, iterations  1100] loss: 1.591 accuracy: 32.522727 %
#
#
# [epoch 0, iterations  1100] loss: 1.561 accuracy: 34.272727 %
# [epoch 0, iterations  1200] loss: 1.559 accuracy: 33.854167 %[epoch 0, iterations  1200] loss: 1.710 accuracy: 32.500000 %[epoch 0, iterations  1200] loss: 1.556 accuracy: 33.479167 %
#
#
# [epoch 0, iterations  1200] loss: 1.574 accuracy: 34.958333 %
# [epoch 0, iterations  1300] loss: 1.500 accuracy: 34.634615 %[epoch 0, iterations  1300] loss: 1.602 accuracy: 33.269231 %
#
# [epoch 0, iterations  1300] loss: 1.692 accuracy: 33.923077 %
# [epoch 0, iterations  1300] loss: 1.568 accuracy: 35.538462 %
# [2023-07-27 08:43:25,948] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:25,948] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:25,948] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:25,948] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:25,948] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:25,948] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:25,948] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:25,949] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [epoch 0, iterations  1400] loss: 1.665 accuracy: 34.982143 %[epoch 0, iterations  1400] loss: 1.580 accuracy: 33.660714 %
#
# [epoch 0, iterations  1400] loss: 1.679 accuracy: 34.125000 %
# [epoch 0, iterations  1400] loss: 1.606 accuracy: 36.160714 %
# [epoch 0, iterations  1500] loss: 1.583 accuracy: 35.533333 %[epoch 0, iterations  1500] loss: 1.602 accuracy: 34.283333 %
#
# [epoch 0, iterations  1500] loss: 1.534 accuracy: 34.700000 %
# [epoch 0, iterations  1500] loss: 1.581 accuracy: 36.600000 %
# [2023-07-27 08:43:26,554] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 1522
# [2023-07-27 08:43:26,554] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 1522
# [2023-07-27 08:43:26,555] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 1522
# [2023-07-27 08:43:26,555] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:26,555] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:26,555] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:26,555] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 1522
# [2023-07-27 08:43:26,555] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:26,555] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 8192.0, reducing to 4096.0
# [epoch 0, iterations  1600] loss: 1.594 accuracy: 34.609375 %[epoch 0, iterations  1600] loss: 1.505 accuracy: 36.125000 %
#
# [epoch 0, iterations  1600] loss: 1.661 accuracy: 34.859375 %
# [epoch 0, iterations  1600] loss: 1.538 accuracy: 37.125000 %
# [epoch 0, iterations  1700] loss: 1.442 accuracy: 35.676471 %
# [epoch 0, iterations  1700] loss: 1.530 accuracy: 36.573529 %[epoch 0, iterations  1700] loss: 1.584 accuracy: 35.176471 %
#
# [epoch 0, iterations  1700] loss: 1.534 accuracy: 37.544118 %
# [epoch 0, iterations  1800] loss: 1.502 accuracy: 36.152778 %[epoch 0, iterations  1800] loss: 1.504 accuracy: 35.750000 %[epoch 0, iterations  1800] loss: 1.487 accuracy: 37.194444 %
#
#
# [epoch 0, iterations  1800] loss: 1.531 accuracy: 37.986111 %
# [epoch 0, iterations  1900] loss: 1.510 accuracy: 37.789474 %[epoch 0, iterations  1900] loss: 1.441 accuracy: 36.828947 %
#
# [epoch 0, iterations  1900] loss: 1.490 accuracy: 38.263158 %
# [epoch 0, iterations  1900] loss: 1.513 accuracy: 36.250000 %
# [epoch 0, iterations  2000] loss: 1.463 accuracy: 37.200000 %
# [epoch 0, iterations  2000] loss: 1.481 accuracy: 36.850000 %
# [epoch 0, iterations  2000] loss: 1.459 accuracy: 38.287500 %
# [2023-07-27 08:43:28,582] [INFO] [logging.py:69:log_dist] [Rank 0] step=2000, skipped=5, lr=[0.001], mom=[[0.8, 0.999]]
# [2023-07-27 08:43:28,583] [INFO] [timer.py:193:stop] 0/2000, SamplesPerSec=3907.5547764482844, MemAllocated=0.0GB, MaxMemAllocated=0.0GB
# [epoch 0, iterations  2000] loss: 1.578 accuracy: 38.325000 %
# [2023-07-27 08:43:28,686] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:28,686] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:28,686] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:28,686] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:28,686] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:28,687] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:28,687] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:28,687] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:28,971] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 2089
# [2023-07-27 08:43:28,971] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 2089
# [2023-07-27 08:43:28,971] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:28,971] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:28,971] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 2089
# [2023-07-27 08:43:28,972] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:28,972] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 2089
# [2023-07-27 08:43:28,972] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:28,972] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 8192.0, reducing to 4096.0
# [epoch 0, iterations  2100] loss: 1.457 accuracy: 38.583333 %[epoch 0, iterations  2100] loss: 1.489 accuracy: 37.607143 %
#
# [epoch 0, iterations  2100] loss: 1.463 accuracy: 37.380952 %
# [epoch 0, iterations  2100] loss: 1.604 accuracy: 38.488095 %
# [epoch 0, iterations  2200] loss: 1.554 accuracy: 37.897727 %[epoch 0, iterations  2200] loss: 1.401 accuracy: 39.193182 %
#
# [epoch 0, iterations  2200] loss: 1.511 accuracy: 37.784091 %
# [epoch 0, iterations  2200] loss: 1.419 accuracy: 38.909091 %
# [epoch 0, iterations  2300] loss: 1.499 accuracy: 39.391304 %[epoch 0, iterations  2300] loss: 1.410 accuracy: 38.445652 %
#
# [epoch 0, iterations  2300] loss: 1.447 accuracy: 38.086957 %
# [epoch 0, iterations  2300] loss: 1.313 accuracy: 39.423913 %
# [epoch 0, iterations  2400] loss: 1.395 accuracy: 39.000000 %[epoch 0, iterations  2400] loss: 1.409 accuracy: 39.843750 %
#
# [epoch 0, iterations  2400] loss: 1.446 accuracy: 38.500000 %
# [epoch 0, iterations  2400] loss: 1.428 accuracy: 39.781250 %
# [epoch 0, iterations  2500] loss: 1.455 accuracy: 40.250000 %
# [epoch 0, iterations  2500] loss: 1.411 accuracy: 39.320000 %
# [epoch 0, iterations  2500] loss: 1.338 accuracy: 39.180000 %
# [epoch 0, iterations  2500] loss: 1.369 accuracy: 40.120000 %
# [2023-07-27 08:43:31,120] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:31,120] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:31,120] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:31,120] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:31,120] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:31,120] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:31,121] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:31,121] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [epoch 0, iterations  2600] loss: 1.416 accuracy: 39.721154 %[epoch 0, iterations  2600] loss: 1.399 accuracy: 40.605769 %
#
# [epoch 0, iterations  2600] loss: 1.399 accuracy: 39.538462 %
# [epoch 0, iterations  2600] loss: 1.419 accuracy: 40.442308 %
# [2023-07-27 08:43:31,224] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 2614
# [2023-07-27 08:43:31,224] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 2614
# [2023-07-27 08:43:31,224] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 2614
# [2023-07-27 08:43:31,224] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:31,224] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:31,224] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:31,224] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 2614
# [2023-07-27 08:43:31,224] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:31,224] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 8192.0, reducing to 4096.0
# [epoch 0, iterations  2700] loss: 1.385 accuracy: 40.240741 %
# [epoch 0, iterations  2700] loss: 1.398 accuracy: 40.879630 %
# [epoch 0, iterations  2700] loss: 1.493 accuracy: 39.768519 %
# [epoch 0, iterations  2700] loss: 1.461 accuracy: 40.629630 %
# [epoch 0, iterations  2800] loss: 1.403 accuracy: 40.116071 %[epoch 0, iterations  2800] loss: 1.438 accuracy: 40.580357 %[epoch 0, iterations  2800] loss: 1.398 accuracy: 41.151786 %
#
#
# [epoch 0, iterations  2800] loss: 1.457 accuracy: 40.750000 %
# [epoch 0, iterations  2900] loss: 1.437 accuracy: 40.827586 %[epoch 0, iterations  2900] loss: 1.326 accuracy: 41.482759 %
# [epoch 0, iterations  2900] loss: 1.320 accuracy: 40.534483 %
#
# [epoch 0, iterations  2900] loss: 1.531 accuracy: 40.939655 %
# [epoch 0, iterations  3000] loss: 1.366 accuracy: 41.216667 %
# [epoch 0, iterations  3000] loss: 1.308 accuracy: 41.833333 %[epoch 0, iterations  3000] loss: 1.398 accuracy: 40.883333 %
#
# [epoch 0, iterations  3000] loss: 1.535 accuracy: 41.100000 %
# [epoch 0, iterations  3100] loss: 1.492 accuracy: 41.516129 %
# [epoch 0, iterations  3100] loss: 1.403 accuracy: 41.217742 %[epoch 0, iterations  3100] loss: 1.457 accuracy: 41.983871 %
#
# [epoch 0, iterations  3100] loss: 1.378 accuracy: 41.379032 %
# [2023-07-27 08:43:33,387] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:33,387] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:33,387] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:33,387] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:33,387] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:33,387] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:33,388] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:33,388] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [epoch 1, iterations   100] loss: 1.356 accuracy: 48.500000 %[epoch 1, iterations   100] loss: 1.314 accuracy: 48.000000 %[epoch 1, iterations   100] loss: 1.394 accuracy: 50.250000 %
#
#
# [epoch 1, iterations   100] loss: 1.334 accuracy: 49.000000 %
# [2023-07-27 08:43:34,220] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 3235
# [2023-07-27 08:43:34,220] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 3235
# [2023-07-27 08:43:34,220] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 3235
# [2023-07-27 08:43:34,220] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:34,220] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:34,220] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:34,221] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 3235
# [2023-07-27 08:43:34,221] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:34,221] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 8192.0, reducing to 4096.0
# [epoch 1, iterations   200] loss: 1.399 accuracy: 48.750000 %[epoch 1, iterations   200] loss: 1.294 accuracy: 48.875000 %
#
# [epoch 1, iterations   200] loss: 1.444 accuracy: 47.375000 %
# [epoch 1, iterations   200] loss: 1.351 accuracy: 49.125000 %
# [epoch 1, iterations   300] loss: 1.469 accuracy: 47.333333 %[epoch 1, iterations   300] loss: 1.370 accuracy: 50.000000 %
#
# [epoch 1, iterations   300] loss: 1.346 accuracy: 49.416667 %
# [epoch 1, iterations   300] loss: 1.329 accuracy: 50.166667 %
# [epoch 1, iterations   400] loss: 1.325 accuracy: 51.187500 %[epoch 1, iterations   400] loss: 1.320 accuracy: 47.937500 %[epoch 1, iterations   400] loss: 1.322 accuracy: 50.125000 %
#
#
# [epoch 1, iterations   400] loss: 1.383 accuracy: 49.375000 %
# [epoch 1, iterations   500] loss: 1.422 accuracy: 50.500000 %[epoch 1, iterations   500] loss: 1.344 accuracy: 50.550000 %[epoch 1, iterations   500] loss: 1.244 accuracy: 49.000000 %
#
#
# [epoch 1, iterations   500] loss: 1.267 accuracy: 50.450000 %
# [epoch 1, iterations   600] loss: 1.350 accuracy: 50.500000 %[epoch 1, iterations   600] loss: 1.352 accuracy: 50.458333 %
# [epoch 1, iterations   600] loss: 1.289 accuracy: 49.750000 %
#
# [epoch 1, iterations   600] loss: 1.302 accuracy: 50.750000 %
# [2023-07-27 08:43:36,364] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:36,364] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:36,364] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:36,364] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:36,364] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:36,364] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:36,364] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:36,365] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [epoch 1, iterations   700] loss: 1.364 accuracy: 50.607143 %[epoch 1, iterations   700] loss: 1.343 accuracy: 50.321429 %
#
# [epoch 1, iterations   700] loss: 1.295 accuracy: 50.607143 %
# [epoch 1, iterations   700] loss: 1.391 accuracy: 50.750000 %
# [2023-07-27 08:43:36,891] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 3857
# [2023-07-27 08:43:36,891] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 3857
# [2023-07-27 08:43:36,891] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 3857
# [2023-07-27 08:43:36,891] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:36,891] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:36,891] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:36,892] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 3857
# [2023-07-27 08:43:36,892] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:36,892] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 8192.0, reducing to 4096.0
# [epoch 1, iterations   800] loss: 1.229 accuracy: 51.468750 %
# [epoch 1, iterations   800] loss: 1.206 accuracy: 51.500000 %[epoch 1, iterations   800] loss: 1.442 accuracy: 50.375000 %
#
# [epoch 1, iterations   800] loss: 1.380 accuracy: 50.812500 %
# [2023-07-27 08:43:37,509] [INFO] [logging.py:69:log_dist] [Rank 0] step=4000, skipped=9, lr=[0.001], mom=[[0.8, 0.999]]
# [2023-07-27 08:43:37,509] [INFO] [timer.py:193:stop] 0/4000, SamplesPerSec=3870.1313708371904, MemAllocated=0.0GB, MaxMemAllocated=0.0GB
# [epoch 1, iterations   900] loss: 1.329 accuracy: 51.500000 %[epoch 1, iterations   900] loss: 1.351 accuracy: 50.583333 %[epoch 1, iterations   900] loss: 1.309 accuracy: 51.388889 %
#
#
# [epoch 1, iterations   900] loss: 1.351 accuracy: 50.861111 %
# [epoch 1, iterations  1000] loss: 1.341 accuracy: 51.350000 %[epoch 1, iterations  1000] loss: 1.317 accuracy: 51.500000 %
#
# [epoch 1, iterations  1000] loss: 1.312 accuracy: 50.625000 %
# [epoch 1, iterations  1000] loss: 1.247 accuracy: 51.450000 %
# [epoch 1, iterations  1100] loss: 1.241 accuracy: 51.818182 %[epoch 1, iterations  1100] loss: 1.302 accuracy: 51.636364 %[epoch 1, iterations  1100] loss: 1.322 accuracy: 50.977273 %
#
#
# [epoch 1, iterations  1100] loss: 1.258 accuracy: 51.659091 %
# [epoch 1, iterations  1200] loss: 1.296 accuracy: 51.979167 %
# [epoch 1, iterations  1200] loss: 1.252 accuracy: 51.854167 %[epoch 1, iterations  1200] loss: 1.409 accuracy: 50.666667 %
#
# [epoch 1, iterations  1200] loss: 1.279 accuracy: 52.000000 %
# [2023-07-27 08:43:39,091] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:39,091] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:39,091] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:39,091] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:39,091] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:39,091] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:39,091] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:39,091] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:39,143] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 4370
# [2023-07-27 08:43:39,143] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 4370
# [2023-07-27 08:43:39,143] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 4370
# [2023-07-27 08:43:39,144] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:39,144] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:39,144] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:39,144] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 4370
# [2023-07-27 08:43:39,144] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:39,144] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 8192.0, reducing to 4096.0
# [epoch 1, iterations  1300] loss: 1.464 accuracy: 51.769231 %[epoch 1, iterations  1300] loss: 1.194 accuracy: 52.134615 %
# [epoch 1, iterations  1300] loss: 1.319 accuracy: 51.038462 %
#
# [epoch 1, iterations  1300] loss: 1.241 accuracy: 52.096154 %
# [epoch 1, iterations  1400] loss: 1.345 accuracy: 51.821429 %
# [epoch 1, iterations  1400] loss: 1.343 accuracy: 52.017857 %[epoch 1, iterations  1400] loss: 1.283 accuracy: 50.964286 %
#
# [epoch 1, iterations  1400] loss: 1.291 accuracy: 52.232143 %
# [epoch 1, iterations  1500] loss: 1.271 accuracy: 52.000000 %[epoch 1, iterations  1500] loss: 1.346 accuracy: 51.133333 %
#
# [epoch 1, iterations  1500] loss: 1.286 accuracy: 52.150000 %
# [epoch 1, iterations  1500] loss: 1.282 accuracy: 52.316667 %
# [epoch 1, iterations  1600] loss: 1.340 accuracy: 51.859375 %[epoch 1, iterations  1600] loss: 1.214 accuracy: 52.312500 %[epoch 1, iterations  1600] loss: 1.311 accuracy: 51.062500 %
#
#
# [epoch 1, iterations  1600] loss: 1.237 accuracy: 52.578125 %
# [epoch 1, iterations  1700] loss: 1.215 accuracy: 52.176471 %
# [epoch 1, iterations  1700] loss: 1.236 accuracy: 52.632353 %[epoch 1, iterations  1700] loss: 1.351 accuracy: 51.000000 %
#
# [epoch 1, iterations  1700] loss: 1.326 accuracy: 52.455882 %
# [2023-07-27 08:43:41,352] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:41,352] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:41,352] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:41,352] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:41,352] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:41,352] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:41,352] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:41,353] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:41,498] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 4904
# [2023-07-27 08:43:41,498] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 4904
# [2023-07-27 08:43:41,498] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 4904
# [2023-07-27 08:43:41,498] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:41,498] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:41,498] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:41,498] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 4904
# [2023-07-27 08:43:41,499] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:41,499] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 8192.0, reducing to 4096.0
# [epoch 1, iterations  1800] loss: 1.276 accuracy: 52.319444 %
# [epoch 1, iterations  1800] loss: 1.263 accuracy: 51.291667 %[epoch 1, iterations  1800] loss: 1.241 accuracy: 52.833333 %
#
# [epoch 1, iterations  1800] loss: 1.263 accuracy: 52.708333 %
# [epoch 1, iterations  1900] loss: 1.187 accuracy: 52.750000 %
# [epoch 1, iterations  1900] loss: 1.293 accuracy: 53.078947 %
# [epoch 1, iterations  1900] loss: 1.288 accuracy: 51.407895 %
# [epoch 1, iterations  1900] loss: 1.200 accuracy: 52.921053 %
# [epoch 1, iterations  2000] loss: 1.227 accuracy: 52.837500 %
# [epoch 1, iterations  2000] loss: 1.234 accuracy: 51.737500 %[epoch 1, iterations  2000] loss: 1.240 accuracy: 53.237500 %
#
# [epoch 1, iterations  2000] loss: 1.318 accuracy: 52.900000 %
# [epoch 1, iterations  2100] loss: 1.235 accuracy: 53.000000 %
# [epoch 1, iterations  2100] loss: 1.214 accuracy: 53.404762 %[epoch 1, iterations  2100] loss: 1.233 accuracy: 52.000000 %
#
# [epoch 1, iterations  2100] loss: 1.392 accuracy: 52.714286 %
# [epoch 1, iterations  2200] loss: 1.354 accuracy: 52.965909 %
# [epoch 1, iterations  2200] loss: 1.323 accuracy: 52.079545 %[epoch 1, iterations  2200] loss: 1.166 accuracy: 53.704545 %
#
# [epoch 1, iterations  2200] loss: 1.226 accuracy: 52.886364 %
# [2023-07-27 08:43:43,718] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:43,718] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:43,718] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:43,718] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:43,718] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:43,718] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:43,719] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:43,719] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [epoch 1, iterations  2300] loss: 1.162 accuracy: 53.206522 %
# [epoch 1, iterations  2300] loss: 1.258 accuracy: 52.163043 %
# [epoch 1, iterations  2300] loss: 1.233 accuracy: 53.782609 %
# [epoch 1, iterations  2300] loss: 1.120 accuracy: 53.141304 %
# [2023-07-27 08:43:44,084] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 5487
# [2023-07-27 08:43:44,084] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 5487
# [2023-07-27 08:43:44,084] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 5487
# [2023-07-27 08:43:44,084] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:44,084] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:44,084] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:44,084] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 5487
# [2023-07-27 08:43:44,084] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:44,084] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 8192.0, reducing to 4096.0
# [epoch 1, iterations  2400] loss: 1.191 accuracy: 53.458333 %
# [epoch 1, iterations  2400] loss: 1.180 accuracy: 53.947917 %
# [epoch 1, iterations  2400] loss: 1.286 accuracy: 52.270833 %
# [epoch 1, iterations  2400] loss: 1.265 accuracy: 53.145833 %
# [epoch 1, iterations  2500] loss: 1.238 accuracy: 53.600000 %
# [epoch 1, iterations  2500] loss: 1.248 accuracy: 53.950000 %
# [epoch 1, iterations  2500] loss: 1.107 accuracy: 52.730000 %
# [epoch 1, iterations  2500] loss: 1.176 accuracy: 53.430000 %
# [epoch 1, iterations  2600] loss: 1.243 accuracy: 53.692308 %
# [epoch 1, iterations  2600] loss: 1.241 accuracy: 54.115385 %[epoch 1, iterations  2600] loss: 1.195 accuracy: 52.913462 %
#
# [epoch 1, iterations  2600] loss: 1.202 accuracy: 53.490385 %
# [epoch 1, iterations  2700] loss: 1.227 accuracy: 53.787037 %
# [epoch 1, iterations  2700] loss: 1.330 accuracy: 52.759259 %[epoch 1, iterations  2700] loss: 1.193 accuracy: 54.268519 %
#
# [epoch 1, iterations  2700] loss: 1.299 accuracy: 53.481481 %
# [epoch 1, iterations  2800] loss: 1.271 accuracy: 53.723214 %
# [epoch 1, iterations  2800] loss: 1.206 accuracy: 54.383929 %[epoch 1, iterations  2800] loss: 1.230 accuracy: 52.910714 %
#
# [epoch 1, iterations  2800] loss: 1.266 accuracy: 53.437500 %
# [2023-07-27 08:43:46,325] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:46,325] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:46,325] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:46,325] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:46,325] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:46,325] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:46,325] [INFO] [fused_optimizer.py:392:_update_scale] No Grad overflow for 500 iterations
# [2023-07-27 08:43:46,326] [INFO] [fused_optimizer.py:394:_update_scale] Increasing dynamic loss scale from 4096.0 to 8192.0
# [2023-07-27 08:43:46,338] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 5991
# [2023-07-27 08:43:46,338] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 5991
# [2023-07-27 08:43:46,338] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 5991
# [2023-07-27 08:43:46,338] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:46,338] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:46,338] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:46,339] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 5991
# [2023-07-27 08:43:46,339] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 8192.0 to 4096.0
# [2023-07-27 08:43:46,339] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 8192.0, reducing to 4096.0
# [2023-07-27 08:43:46,374] [INFO] [logging.py:69:log_dist] [Rank 0] step=6000, skipped=13, lr=[0.001], mom=[[0.8, 0.999]]
# [2023-07-27 08:43:46,375] [INFO] [timer.py:193:stop] 0/6000, SamplesPerSec=3844.5150626542377, MemAllocated=0.0GB, MaxMemAllocated=0.0GB
# [epoch 1, iterations  2900] loss: 1.283 accuracy: 53.672414 %
# [epoch 1, iterations  2900] loss: 1.140 accuracy: 54.551724 %
# [epoch 1, iterations  2900] loss: 1.142 accuracy: 53.146552 %
# [epoch 1, iterations  2900] loss: 1.372 accuracy: 53.517241 %
# [epoch 1, iterations  3000] loss: 1.221 accuracy: 53.850000 %
# [epoch 1, iterations  3000] loss: 1.130 accuracy: 54.733333 %[epoch 1, iterations  3000] loss: 1.241 accuracy: 53.316667 %
#
# [epoch 1, iterations  3000] loss: 1.327 accuracy: 53.558333 %
# [2023-07-27 08:43:47,287] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 6206
# [2023-07-27 08:43:47,287] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 6206
# [2023-07-27 08:43:47,287] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 4096.0 to 2048.0
# [2023-07-27 08:43:47,287] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 4096.0 to 2048.0
# [2023-07-27 08:43:47,287] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 6206
# [2023-07-27 08:43:47,287] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 4096.0 to 2048.0
# [2023-07-27 08:43:47,287] [INFO] [fused_optimizer.py:382:_update_scale]
# Grad overflow on iteration 6206
# [2023-07-27 08:43:47,288] [INFO] [fused_optimizer.py:383:_update_scale] Reducing dynamic loss scale from 4096.0 to 2048.0
# [2023-07-27 08:43:47,288] [INFO] [logging.py:69:log_dist] [Rank 0] Overflow detected. Skipping step. Attempted loss scale: 4096.0, reducing to 2048.0
# [epoch 1, iterations  3100] loss: 1.287 accuracy: 53.951613 %
# [epoch 1, iterations  3100] loss: 1.290 accuracy: 54.596774 %[epoch 1, iterations  3100] loss: 1.187 accuracy: 53.500000 %
#
# [epoch 1, iterations  3100] loss: 1.247 accuracy: 53.588710 %
# Training Done
# Training Done
# Training Done
# Training Done
# Accuracy of the network on the 10000 test images: 56.070000 %
# Accuracy of plane : 64.600000 %
# Accuracy of   car : 76.800000 %
# Accuracy of  bird : 35.800000 %
# Accuracy of   cat : 29.000000 %
# Accuracy of  deer : 44.700000 %
# Accuracy of   dog : 46.800000 %
# Accuracy of  frog : 63.100000 %
# Accuracy of horse : 74.800000 %
# Accuracy of  ship : 77.700000 %
# Accuracy of truck : 47.400000 %
# Evaluation Done
# Accuracy of the network on the 10000 test images: 56.070000 %
# Accuracy of plane : 64.600000 %
# Accuracy of   car : 76.800000 %
# Accuracy of  bird : 35.800000 %
# Accuracy of   cat : 29.000000 %
# Accuracy of  deer : 44.700000 %
# Accuracy of   dog : 46.800000 %
# Accuracy of  frog : 63.100000 %
# Accuracy of horse : 74.800000 %
# Accuracy of  ship : 77.700000 %
# Accuracy of truck : 47.400000 %
# Evaluation Done
# Accuracy of the network on the 10000 test images: 56.070000 %
# Accuracy of plane : 64.600000 %
# Accuracy of   car : 76.800000 %
# Accuracy of  bird : 35.800000 %
# Accuracy of   cat : 29.000000 %
# Accuracy of  deer : 44.700000 %
# Accuracy of   dog : 46.800000 %
# Accuracy of  frog : 63.100000 %
# Accuracy of horse : 74.800000 %
# Accuracy of  ship : 77.700000 %
# Accuracy of truck : 47.400000 %
# Evaluation Done
# Accuracy of the network on the 10000 test images: 56.070000 %
# Accuracy of plane : 64.600000 %
# Accuracy of   car : 76.800000 %
# Accuracy of  bird : 35.800000 %
# Accuracy of   cat : 29.000000 %
# Accuracy of  deer : 44.700000 %
# Accuracy of   dog : 46.800000 %
# Accuracy of  frog : 63.100000 %
# Accuracy of horse : 74.800000 %
# Accuracy of  ship : 77.700000 %
# Accuracy of truck : 47.400000 %
# Evaluation Done
# [2023-07-27 08:43:53,058] [INFO] [launch.py:210:main] Process 6068 exits successfully.
# [2023-07-27 08:43:53,058] [INFO] [launch.py:210:main] Process 6066 exits successfully.
# [2023-07-27 08:43:53,059] [INFO] [launch.py:210:main] Process 6067 exits successfully.
# [2023-07-27 08:43:54,060] [INFO] [launch.py:210:main] Process 6065 exits successfully.

# %% [markdown]
# To execute the same run on a SLURM based cluster, simply write the SBATCH script allocating the desired resources and invoke the same DeepSpeed command.
#
# Run the next cell to create the SBATCH script allocating 2 nodes to run the previous training with DeepSpeed.

# %%
# %%writefile /dli/code/run_cifar10_deepspeed_2Nodes.sh
# #!/bin/bash
# #SBATCH --job-name=dli_ds
# #SBATCH --nodes=2
# #SBATCH --ntasks-per-node=1
# #SBATCH --cpus-per-task=32 ### Number of threads per task (OMP threads)
# #SBATCH -o /dli/megatron/logs/%j.out
# #SBATCH -e /dli/megatron/logs/%j.err
#
# # Number of nodes
# NUM_NODES=2
# # Number of GPUs per node
# NUM_GPUS=2
#
#
# deepspeed --num_nodes=${NUM_NODES} --hostfile /dli/code/moe/hostfile --num_gpus=${NUM_GPUS} /dli/code/moe/cifar10_deepspeed.py \
#     --deepspeed \
#     --deepspeed_config /dli/code/moe/ds_config.json \
#     --profile-execution=True \
#     --profile-name='zero0_sbatch'
# Out:
# Writing /dli/code/run_cifar10_deepspeed_2Nodes.sh

# %% [markdown]
# Now, let's submit the previous sbatch script [run_cifar10_deepspeed_2Nodes.sh](./code/run_cifar10_deepspeed_2Nodes.sh) and check the SLURM queue using the `squeue` command.

# %%
# Submit the 2 nodes jobs
# !sbatch /dli/code/run_cifar10_deepspeed_2Nodes.sh

# Check the SLURM queue
# !squeue
# Out:
# Submitted batch job 5
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#                  5  slurmpar   dli_ds    admin PD       0:00      2 (None)

# %%
# Check GPU utilization on the master node
# !sleep 10
# !nvidia-smi
# Out:
# Thu Jul 27 08:44:07 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.5     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Graphics Device     On   | 00000001:00:00.0 Off |                    0 |
# | N/A   40C    P0    79W / 300W |   1326MiB / 81251MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   1  Graphics Device     On   | 00000002:00:00.0 Off |                    0 |
# | N/A   40C    P0    77W / 300W |   1332MiB / 81251MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   2  Graphics Device     On   | 00000003:00:00.0 Off |                    0 |
# | N/A   39C    P0    77W / 300W |   1316MiB / 81251MiB |      1%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
# |   3  Graphics Device     On   | 00000004:00:00.0 Off |                    0 |
# | N/A   39C    P0    74W / 300W |   1364MiB / 81251MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## 5.2.3 Zero Redundancy Optimizer
#
# [ZeRO](https://www.deepspeed.ai/tutorials/zero/) reduces the memory consumption of each GPU by distributing the model's training states (weights, gradients, and optimizer states) across the available devices. ZeRO is implemented as 3 accumulative stages:
#
# - **ZeRO-1:** The optimizer states are partitioned across the processes, so that each process updates only its partition. For instance, the Adam optimizer will store 32-bit weights, and the first, and second moment estimates.
# - **ZeRO-2:** In addition to Zero 1, the reduced 32-bit gradients for updating the model weights are also partitioned such that each process retains only the gradients corresponding to its portion of the optimizer states.
# - **ZeRO-3:** In addition to Zero 2, the 16-bit model parameters are partitioned across the processes. ZeRO-3 will automatically collect and partition them during the forward and backward passes. ZeRO-3 also includes the [ZeRO-Infinity](https://arxiv.org/pdf/2104.07857.pdf) engine that offloads to both CPU and NVMe memory for memory savings.
#
# ```
# {
#  "zero_optimization": {
#     "stage": [0|1|2|3],
#     "allgather_partitions": [true|false],
#     "allgather_bucket_size": 5e8,
#     "overlap_comm": false,
#     "reduce_scatter": [true|false],
#     "reduce_bucket_size": 5e8,
#     "contiguous_gradients" : [true|false],
#     "offload_param": {
#       ...
#     },
#     "offload_optimizer": {
#       ...
#     },
#     "stage3_max_live_parameters" : 1e9,
#     "stage3_max_reuse_distance" : 1e9,
#     "stage3_prefetch_bucket_size" : 5e8,
#     "stage3_param_persistence_threshold" : 1e6,
#     "sub_group_size" : 1e12,
#     "elastic_checkpoint" : [true|false],
#     "stage3_gather_16bit_weights_on_model_save": [true|false],
#     "ignore_unused_parameters": [true|false]
#     "round_robin_gradients": [true|false]
#     }
#   }
#
# ```

# %% [markdown]
# <video controls src="https://www.microsoft.com/en-us/research/uploads/prod/2020/02/Turing-Animation.mp4?_=1" width="560" />

# %% [markdown]
# In order to illustrate the advantages of ZeRO optimizer in memory saving, let's scale our CNN model to a larger neural network. We  replaced the tiny CNN network with the Resnet152 model with 11 million parameters in the [large_model_deepspeed.py](./code/moe/large_model_deepspeed.py).
#
#
# The following figure shows the CPU usage via [htop](https://htop.dev/) command and the GPU 0 memory profiled using Pytorch Profiler (available on the Tensorboard) for the *resnet152* training step. We can see a comparison between no ZeRO and ZeRO stage 3 + Offload. The memory peak required per GPU without ZeRO optimizer is about 1.5GB, while offloading the parameters to the CPU with ZeRO-3 uses only 845MB. On the other hand, the time per step increased significantly from 500ms to 7000ms!
#
# ZeRO infinity allows sacling to larger models when the number of GPUs are limited, but this comes with an additional training time corresponding to data movement.
# <img src="images/zero_memory.png" width="1250" />
#
#
# Let's run the Zero stage 3 optimizer and enable CPU offload of the parameters. We have prepared the configuration file. Notice that we have increased the training batch size per GPU to 512.

# %%
# Show DeepSpeed config file for Zero stage 3 Offload
# !cat /dli/code/moe/ds_config_stage_3.json
# Out:
# {
#   "train_batch_size": 512,
#   "steps_per_print": 2000,
#   "optimizer": {
#     "type": "Adam",
#     "params": {
#       "lr": 0.001,
#       "betas": [
#         0.8,
#         0.999
#       ],
#       "eps": 1e-8,
#       "weight_decay": 3e-7
#     }
#   },
#   "scheduler": {
#     "type": "WarmupLR",
#     "params": {
#       "warmup_min_lr": 0,
#       "warmup_max_lr": 0.001,
#       "warmup_num_steps": 1000
#     }
#   },
#   "gradient_clipping": 1.0,
#   "prescale_gradients": false,
#   "fp16": {
#       "enabled": true,
#       "fp16_master_weights_and_grads": false,
#       "loss_scale": 0,
#       "loss_scale_window": 500,
#       "hysteresis": 2,
#       "min_loss_scale": 1,
#       "initial_scale_power": 15
#   },
#   "wall_clock_breakdown": false,
#     "zero_optimization": {
#         "stage": 3,
#         "offload_param": {
#           "device": "cpu"
#         },
#         "offload_optimizer": {
#           "device": "cpu"
#         },
#         "cpu_offload_use_pin_memory" : true,
#         "overlap_comm": true,
#         "contiguous_gradients": true,
#         "stage3_max_live_parameters": 1e9,
#         "stage3_max_reuse_distance": 1e9,
#         "stage3_prefetch_bucket_size": 0.94e6,
#         "stage3_param_persistence_threshold": 1e4,
#         "reduce_bucket_size": 1e6,
#         "prefetch_bucket_size": 3e6,
#         "sub_group_size": 1e14,
#         "stage3_gather_fp16_weights_on_model_save": true
#     }
# }

# %% [markdown]
# First, let's download the resnet152 model. More information about it can be found [here](https://pytorch.org/hub/pytorch_vision_resnet/)

# %%
import torch
net = torch.hub.load("pytorch/vision:v0.10.0", "resnet152", force_reload=True, pretrained=True)
# Out:
# Downloading: "https://github.com/pytorch/vision/archive/v0.10.0.zip" to /home/admin/.cache/torch/hub/v0.10.0.zip
# Downloading: "https://download.pytorch.org/models/resnet152-394f9c45.pth" to /home/admin/.cache/torch/hub/checkpoints/resnet152-394f9c45.pth
#   0%|          | 0.00/230M [00:00<?, ?B/s]

# %% [markdown]
# Execute the next cell to run the *resnet152* model training on the CIFAR-10 dataset. Notice that in these experiments, our focus is memory consumption as opposed to model accuracy.

# %%
# !deepspeed --num_gpus=4 /dli/code/moe/large_model_deepspeed.py \
    --deepspeed \
    --deepspeed_config /dli/code/moe/ds_config_stage_3.json \
    --profile-execution=True \
    --profile-name='zero_resnet152_stage3'
# Out:
# [2023-07-27 08:45:17,082] [WARNING] [runner.py:159:fetch_hostfile] Unable to find hostfile, will proceed with training with local resources only.
# [2023-07-27 08:45:17,335] [INFO] [runner.py:457:main] cmd = /opt/conda/bin/python3.8 -u -m deepspeed.launcher.launch --world_info=eyJsb2NhbGhvc3QiOiBbMCwgMSwgMiwgM119 --master_addr=127.0.0.1 --master_port=29500 /dli/code/moe/large_model_deepspeed.py --deepspeed --deepspeed_config /dli/code/moe/ds_config_stage_3.json --profile-execution=True --profile-name=zero_resnet152_stage3
# [2023-07-27 08:45:18,361] [INFO] [launch.py:96:main] 0 NCCL_P2P_DISABLE=1
# [2023-07-27 08:45:18,361] [INFO] [launch.py:96:main] 0 NCCL_VERSION=2.11.4
# [2023-07-27 08:45:18,361] [INFO] [launch.py:103:main] WORLD INFO DICT: {'localhost': [0, 1, 2, 3]}
# [2023-07-27 08:45:18,361] [INFO] [launch.py:109:main] nnodes=1, num_local_procs=4, node_rank=0
# [2023-07-27 08:45:18,361] [INFO] [launch.py:122:main] global_rank_mapping=defaultdict(<class 'list'>, {'localhost': [0, 1, 2, 3]})
# [2023-07-27 08:45:18,361] [INFO] [launch.py:123:main] dist_world_size=4
# [2023-07-27 08:45:18,361] [INFO] [launch.py:125:main] Setting CUDA_VISIBLE_DEVICES=0,1,2,3
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Using cache found in /home/admin/.cache/torch/hub/pytorch_vision_v0.10.0
# Using cache found in /home/admin/.cache/torch/hub/pytorch_vision_v0.10.0
# Using cache found in /home/admin/.cache/torch/hub/pytorch_vision_v0.10.0
# Using cache found in /home/admin/.cache/torch/hub/pytorch_vision_v0.10.0
# [2023-07-27 08:45:21,571] [INFO] [logging.py:69:log_dist] [Rank -1] DeepSpeed info: version=0.6.5, git-hash=unknown, git-branch=unknown
# [2023-07-27 08:45:21,575] [INFO] [distributed.py:48:init_distributed] Initializing torch distributed with backend: nccl
# [2023-07-27 08:45:21,634] [INFO] [logging.py:69:log_dist] [Rank -1] DeepSpeed info: version=0.6.5, git-hash=unknown, git-branch=unknown
# [2023-07-27 08:45:21,691] [INFO] [logging.py:69:log_dist] [Rank -1] DeepSpeed info: version=0.6.5, git-hash=unknown, git-branch=unknown
# [2023-07-27 08:45:21,808] [INFO] [logging.py:69:log_dist] [Rank -1] DeepSpeed info: version=0.6.5, git-hash=unknown, git-branch=unknown
# [2023-07-27 08:45:24,530] [INFO] [engine.py:278:__init__] DeepSpeed Flops Profiler Enabled: False
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# Creating extension directory /home/admin/.cache/torch_extensions/py38_cu115/cpu_adam...
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/admin/.cache/torch_extensions/py38_cu115/cpu_adam/build.ninja...
# Building extension module cpu_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# [1/3] /usr/local/cuda/bin/nvcc  -DTORCH_EXTENSION_NAME=cpu_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1013\" -I/opt/conda/lib/python3.8/site-packages/deepspeed/ops/csrc/includes -I/usr/local/cuda/include -isystem /opt/conda/lib/python3.8/site-packages/torch/include -isystem /opt/conda/lib/python3.8/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.8/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.8/site-packages/torch/include/THC -isystem /usr/local/cuda/include -isystem /opt/conda/include/python3.8 -D_GLIBCXX_USE_CXX11_ABI=1 -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -gencode=arch=compute_80,code=compute_80 -gencode=arch=compute_80,code=sm_80 --compiler-options '-fPIC' -O3 --use_fast_math -std=c++14 -U__CUDA_NO_HALF_OPERATORS__ -U__CUDA_NO_HALF_CONVERSIONS__ -U__CUDA_NO_HALF2_OPERATORS__ -gencode=arch=compute_80,code=sm_80 -gencode=arch=compute_80,code=compute_80 -c /opt/conda/lib/python3.8/site-packages/deepspeed/ops/csrc/common/custom_cuda_kernel.cu -o custom_cuda_kernel.cuda.o
# [2/3] c++ -MMD -MF cpu_adam.o.d -DTORCH_EXTENSION_NAME=cpu_adam -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1013\" -I/opt/conda/lib/python3.8/site-packages/deepspeed/ops/csrc/includes -I/usr/local/cuda/include -isystem /opt/conda/lib/python3.8/site-packages/torch/include -isystem /opt/conda/lib/python3.8/site-packages/torch/include/torch/csrc/api/include -isystem /opt/conda/lib/python3.8/site-packages/torch/include/TH -isystem /opt/conda/lib/python3.8/site-packages/torch/include/THC -isystem /usr/local/cuda/include -isystem /opt/conda/include/python3.8 -D_GLIBCXX_USE_CXX11_ABI=1 -fPIC -std=c++14 -O3 -std=c++14 -g -Wno-reorder -L/usr/local/cuda/lib64 -lcudart -lcublas -g -march=native -fopenmp -D__AVX256__ -c /opt/conda/lib/python3.8/site-packages/deepspeed/ops/csrc/adam/cpu_adam.cpp -o cpu_adam.o
# [3/3] c++ cpu_adam.o custom_cuda_kernel.cuda.o -shared -lcurand -L/opt/conda/lib/python3.8/site-packages/torch/lib -lc10 -lc10_cuda -ltorch_cpu -ltorch_cuda -ltorch -ltorch_python -L/usr/local/cuda/lib64 -lcudart -o cpu_adam.so
# Loading extension module cpu_adam...
# Time to load cpu_adam op: 21.66718864440918 seconds
# Loading extension module cpu_adam...
# Time to load cpu_adam op: 21.636582136154175 seconds
# Loading extension module cpu_adam...
# Time to load cpu_adam op: 21.64778184890747 seconds
# Loading extension module cpu_adam...
# Time to load cpu_adam op: 21.73383069038391 seconds
# Adam Optimizer #0 is created with AVX2 arithmetic capability.
# Config: alpha=0.001000, betas=(0.800000, 0.999000), weight_decay=0.000000, adam_w=1
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# Adam Optimizer #0 is created with AVX2 arithmetic capability.
# Config: alpha=0.001000, betas=(0.800000, 0.999000), weight_decay=0.000000, adam_w=1
# Adam Optimizer #0 is created with AVX2 arithmetic capability.
# Config: alpha=0.001000, betas=(0.800000, 0.999000), weight_decay=0.000000, adam_w=1
# Adam Optimizer #0 is created with AVX2 arithmetic capability.
# Config: alpha=0.001000, betas=(0.800000, 0.999000), weight_decay=0.000000, adam_w=1
# [2023-07-27 08:45:47,453] [INFO] [engine.py:1100:_configure_optimizer] Using DeepSpeed Optimizer param name adam as basic optimizer
# Emitting ninja build file /home/admin/.cache/torch_extensions/py38_cu115/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# [2023-07-27 08:45:47,477] [INFO] [engine.py:1108:_configure_optimizer] DeepSpeed Basic Optimizer = DeepSpeedCPUAdam
# [2023-07-27 08:45:47,477] [INFO] [utils.py:52:is_zero_supported_optimizer] Checking ZeRO support for optimizer=DeepSpeedCPUAdam type=<class 'deepspeed.ops.adam.cpu_adam.DeepSpeedCPUAdam'>
# [2023-07-27 08:45:47,477] [INFO] [logging.py:69:log_dist] [Rank 0] Creating fp16 ZeRO stage 3 optimizer
# [2023-07-27 08:45:47,477] [INFO] [engine.py:1410:_configure_zero_optimizer] Initializing ZeRO Stage 3
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# [2023-07-27 08:45:47,486] [INFO] [stage3.py:275:__init__] Reduce bucket size 1000000.0
# [2023-07-27 08:45:47,486] [INFO] [stage3.py:276:__init__] Prefetch bucket size 940000.0
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# ninja: no work to do.
# Loading extension module utils...
# Time to load utils op: 0.11306285858154297 seconds
# Loading extension module utils...
# Time to load utils op: 0.10255694389343262 seconds
# Loading extension module utils...
# Time to load utils op: 0.10210680961608887 seconds
# Loading extension module utils...
# Time to load utils op: 0.10265779495239258 seconds
# [2023-07-27 08:45:48,281] [INFO] [stage3.py:567:_setup_for_real_optimizer] optimizer state initialized
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00035643577575683594 seconds
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00045800209045410156 seconds
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.001176595687866211 seconds
# [2023-07-27 08:45:48,681] [INFO] [utils.py:828:see_memory_usage] After initializing ZeRO optimizer
# [2023-07-27 08:45:48,682] [INFO] [utils.py:829:see_memory_usage] MA 0.0 GB         Max_MA 0.11 GB         CA 0.12 GB         Max_CA 0 GB
# [2023-07-27 08:45:48,682] [INFO] [utils.py:837:see_memory_usage] CPU Virtual Memory:  used = 25.97 GB, percent = 3.0%
# [2023-07-27 08:45:48,682] [INFO] [logging.py:69:log_dist] [Rank 0] DeepSpeed Final Optimizer = adam
# [2023-07-27 08:45:48,682] [INFO] [engine.py:785:_configure_lr_scheduler] DeepSpeed using configured LR scheduler = WarmupLR
# [2023-07-27 08:45:48,682] [INFO] [logging.py:69:log_dist] [Rank 0] DeepSpeed LR Scheduler = <deepspeed.runtime.lr_schedules.WarmupLR object at 0x7fbefa968fd0>
# [2023-07-27 08:45:48,682] [INFO] [logging.py:69:log_dist] [Rank 0] step=0, skipped=0, lr=[0.001], mom=[[0.8, 0.999]]
# [2023-07-27 08:45:48,683] [INFO] [config.py:1059:print] DeepSpeedEngine configuration:
# [2023-07-27 08:45:48,683] [INFO] [config.py:1063:print]   activation_checkpointing_config  {
#     "partition_activations": false,
#     "contiguous_memory_optimization": false,
#     "cpu_checkpointing": false,
#     "number_checkpoints": null,
#     "synchronize_checkpoint_boundary": false,
#     "profile": false
# }
# [2023-07-27 08:45:48,683] [INFO] [config.py:1063:print]   aio_config ................... {'block_size': 1048576, 'queue_depth': 8, 'thread_count': 1, 'single_submit': False, 'overlap_events': True}
# [2023-07-27 08:45:48,683] [INFO] [config.py:1063:print]   amp_enabled .................. False
# [2023-07-27 08:45:48,683] [INFO] [config.py:1063:print]   amp_params ................... False
# [2023-07-27 08:45:48,683] [INFO] [config.py:1063:print]   autotuning_config ............ {
#     "enabled": false,
#     "start_step": null,
#     "end_step": null,
#     "metric_path": null,
#     "arg_mappings": null,
#     "metric": "throughput",
#     "model_info": null,
#     "results_dir": null,
#     "exps_dir": null,
#     "overwrite": true,
#     "fast": true,
#     "start_profile_step": 3,
#     "end_profile_step": 5,
#     "tuner_type": "gridsearch",
#     "tuner_early_stopping": 5,
#     "tuner_num_trials": 50,
#     "model_info_path": null,
#     "mp_size": 1,
#     "max_train_batch_size": null,
#     "min_train_batch_size": 1,
#     "max_train_micro_batch_size_per_gpu": 1.024000e+03,
#     "min_train_micro_batch_size_per_gpu": 1,
#     "num_tuning_micro_batch_sizes": 3
# }
# [2023-07-27 08:45:48,683] [INFO] [config.py:1063:print]   bfloat16_enabled ............. False
# [2023-07-27 08:45:48,683] [INFO] [config.py:1063:print]   checkpoint_tag_validation_enabled  True
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   checkpoint_tag_validation_fail  False
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   communication_data_type ...... None
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   curriculum_enabled ........... False
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   curriculum_params ............ False
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   dataloader_drop_last ......... False
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   disable_allgather ............ False
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   dump_state ................... False
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   dynamic_loss_scale_args ...... {'init_scale': 32768, 'scale_window': 500, 'delayed_shift': 2, 'min_scale': 1}
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   eigenvalue_enabled ........... False
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   eigenvalue_gas_boundary_resolution  1
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   eigenvalue_layer_name ........ bert.encoder.layer
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   eigenvalue_layer_num ......... 0
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   eigenvalue_max_iter .......... 100
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   eigenvalue_stability ......... 1e-06
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   eigenvalue_tol ............... 0.01
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   eigenvalue_verbose ........... False
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   elasticity_enabled ........... False
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   flops_profiler_config ........ {
#     "enabled": false,
#     "profile_step": 1,
#     "module_depth": -1,
#     "top_modules": 1,
#     "detailed": true,
#     "output_file": null
# }
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   fp16_enabled ................. True
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   fp16_master_weights_and_gradients  False
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   fp16_mixed_quantize .......... False
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   global_rank .................. 0
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   gradient_accumulation_steps .. 1
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   gradient_clipping ............ 1.0
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   gradient_predivide_factor .... 1.0
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   initial_dynamic_scale ........ 32768
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   loss_scale ................... 0
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   memory_breakdown ............. False
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   optimizer_legacy_fusion ...... False
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   optimizer_name ............... adam
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   optimizer_params ............. {'lr': 0.001, 'betas': [0.8, 0.999], 'eps': 1e-08, 'weight_decay': 3e-07}
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   pipeline ..................... {'stages': 'auto', 'partition': 'best', 'seed_layers': False, 'activation_checkpoint_interval': 0}
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   pld_enabled .................. False
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   pld_params ................... False
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   prescale_gradients ........... False
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   quantize_change_rate ......... 0.001
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   quantize_groups .............. 1
# [2023-07-27 08:45:48,684] [INFO] [config.py:1063:print]   quantize_offset .............. 1000
# [2023-07-27 08:45:48,685] [INFO] [config.py:1063:print]   quantize_period .............. 1000
# [2023-07-27 08:45:48,685] [INFO] [config.py:1063:print]   quantize_rounding ............ 0
# [2023-07-27 08:45:48,685] [INFO] [config.py:1063:print]   quantize_start_bits .......... 16
# [2023-07-27 08:45:48,685] [INFO] [config.py:1063:print]   quantize_target_bits ......... 8
# [2023-07-27 08:45:48,685] [INFO] [config.py:1063:print]   quantize_training_enabled .... False
# [2023-07-27 08:45:48,685] [INFO] [config.py:1063:print]   quantize_type ................ 0
# [2023-07-27 08:45:48,685] [INFO] [config.py:1063:print]   quantize_verbose ............. False
# [2023-07-27 08:45:48,685] [INFO] [config.py:1063:print]   scheduler_name ............... WarmupLR
# [2023-07-27 08:45:48,685] [INFO] [config.py:1063:print]   scheduler_params ............. {'warmup_min_lr': 0, 'warmup_max_lr': 0.001, 'warmup_num_steps': 1000}
# [2023-07-27 08:45:48,685] [INFO] [config.py:1063:print]   sparse_attention ............. None
# [2023-07-27 08:45:48,685] [INFO] [config.py:1063:print]   sparse_gradients_enabled ..... False
# [2023-07-27 08:45:48,685] [INFO] [config.py:1063:print]   steps_per_print .............. 2000
# [2023-07-27 08:45:48,685] [INFO] [config.py:1063:print]   tensorboard_enabled .......... False
# [2023-07-27 08:45:48,685] [INFO] [config.py:1063:print]   tensorboard_job_name ......... DeepSpeedJobName
# [2023-07-27 08:45:48,685] [INFO] [config.py:1063:print]   tensorboard_output_path ......
# [2023-07-27 08:45:48,685] [INFO] [config.py:1063:print]   train_batch_size ............. 512
# [2023-07-27 08:45:48,685] [INFO] [config.py:1063:print]   train_micro_batch_size_per_gpu  128
# [2023-07-27 08:45:48,685] [INFO] [config.py:1063:print]   use_quantizer_kernel ......... False
# [2023-07-27 08:45:48,685] [INFO] [config.py:1063:print]   wall_clock_breakdown ......... False
# [2023-07-27 08:45:48,685] [INFO] [config.py:1063:print]   world_size ................... 4
# [2023-07-27 08:45:48,685] [INFO] [config.py:1063:print]   zero_allow_untested_optimizer  False
# [2023-07-27 08:45:48,685] [INFO] [config.py:1063:print]   zero_config .................. {
#     "stage": 3,
#     "contiguous_gradients": true,
#     "reduce_scatter": true,
#     "reduce_bucket_size": 1.000000e+06,
#     "allgather_partitions": true,
#     "allgather_bucket_size": 5.000000e+08,
#     "overlap_comm": true,
#     "load_from_fp32_weights": true,
#     "elastic_checkpoint": false,
#     "offload_param": {
#         "device": "cpu",
#         "nvme_path": null,
#         "buffer_count": 5,
#         "buffer_size": 1.000000e+08,
#         "max_in_cpu": 1.000000e+09,
#         "pin_memory": false
#     },
#     "offload_optimizer": {
#         "device": "cpu",
#         "nvme_path": null,
#         "buffer_count": 4,
#         "pin_memory": false,
#         "pipeline_read": false,
#         "pipeline_write": false,
#         "fast_init": false,
#         "pipeline": false
#     },
#     "sub_group_size": 1.000000e+14,
#     "prefetch_bucket_size": 9.400000e+05,
#     "param_persistence_threshold": 1.000000e+04,
#     "max_live_parameters": 1.000000e+09,
#     "max_reuse_distance": 1.000000e+09,
#     "gather_16bit_weights_on_model_save": true,
#     "ignore_unused_parameters": true,
#     "round_robin_gradients": false,
#     "legacy_stage1": false
# }
# [2023-07-27 08:45:48,685] [INFO] [config.py:1063:print]   zero_enabled ................. True
# [2023-07-27 08:45:48,685] [INFO] [config.py:1063:print]   zero_optimization_stage ...... 3
# [2023-07-27 08:45:48,685] [INFO] [config.py:1065:print]   json = {
#     "train_batch_size": 512,
#     "steps_per_print": 2.000000e+03,
#     "optimizer": {
#         "type": "Adam",
#         "params": {
#             "lr": 0.001,
#             "betas": [0.8, 0.999],
#             "eps": 1e-08,
#             "weight_decay": 3e-07
#         }
#     },
#     "scheduler": {
#         "type": "WarmupLR",
#         "params": {
#             "warmup_min_lr": 0,
#             "warmup_max_lr": 0.001,
#             "warmup_num_steps": 1000
#         }
#     },
#     "gradient_clipping": 1.0,
#     "prescale_gradients": false,
#     "fp16": {
#         "enabled": true,
#         "fp16_master_weights_and_grads": false,
#         "loss_scale": 0,
#         "loss_scale_window": 500,
#         "hysteresis": 2,
#         "min_loss_scale": 1,
#         "initial_scale_power": 15
#     },
#     "wall_clock_breakdown": false,
#     "zero_optimization": {
#         "stage": 3,
#         "offload_param": {
#             "device": "cpu"
#         },
#         "offload_optimizer": {
#             "device": "cpu"
#         },
#         "cpu_offload_use_pin_memory": true,
#         "overlap_comm": true,
#         "contiguous_gradients": true,
#         "stage3_max_live_parameters": 1.000000e+09,
#         "stage3_max_reuse_distance": 1.000000e+09,
#         "stage3_prefetch_bucket_size": 9.400000e+05,
#         "stage3_param_persistence_threshold": 1.000000e+04,
#         "reduce_bucket_size": 1.000000e+06,
#         "prefetch_bucket_size": 3.000000e+06,
#         "sub_group_size": 1.000000e+14,
#         "stage3_gather_fp16_weights_on_model_save": true
#     }
# }
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0003445148468017578 seconds
# [2023-07-27 08:45:52,189] [INFO] [stage3.py:2281:_overflow_clean_up] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 32768, reducing to 32768
# [2023-07-27 08:45:57,340] [INFO] [stage3.py:2281:_overflow_clean_up] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 32768, reducing to 16384.0
# [2023-07-27 08:46:03,854] [INFO] [stage3.py:2281:_overflow_clean_up] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 16384.0, reducing to 8192.0
# [2023-07-27 08:46:05,766] [INFO] [stage3.py:2281:_overflow_clean_up] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 8192.0, reducing to 4096.0
# Training Done
# Training Done
# Training Done
# Training Done
# Cannot insert a Tensor that requires grad as a constant. Consider making it a parameter or input, or detaching the gradient
# Tensor:
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0061
#  0.0047
# -0.0123
#  0.0173
#  0.0819
#  0.0101
#  0.0040
#  0.0216
#  0.0173
# -0.0221
#  0.0071
# -0.0031
#  0.0179
# -0.0249
#  0.0619
#  0.0049
#  0.0598
#  0.0400
#  0.0122
# -0.0069
# -0.0049
#  0.0036
#  0.0091
# -0.0026
# -0.0143
# -0.0055
# -0.0137
#  0.0026
# -0.0594
# -0.0401
# -0.0331
# -0.0446
# -0.0596
# -0.0169
# -0.0568
# -0.0329
#  0.0115
# -0.0023
#  0.0242
# -0.0005
#  0.0253
#  0.0399
#  0.0102
#  0.0290
# -0.0035
# -0.0031
#  0.0116
#  0.0097
# -0.0089
#  0.0007
#  0.0040
#  0.0014
# -0.0040
# -0.0052
# -0.0124
# -0.0285
# -0.0398
# -0.0763
#  0.0235
# -0.1300
# -0.0359
# -0.0963
# -0.0807
#  0.0233
#  0.0508
#  0.0399
#  0.0309
#  0.0053
#  0.0545
#  0.0193
#  0.0311
#  0.0311
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0043
#  0.0143
#  0.0096
#  0.0222
#  0.0134
#  0.0615
#  0.0072
#  0.0751
#  0.0467
# -0.0071
#  0.0017
# -0.0143
# -0.0165
# -0.0405
#  0.0162
# -0.0048
# -0.0218
#  0.0346
#  0.0079
#  0.0003
#  0.0013
# -0.0037
# -0.0583
# -0.0261
# -0.0170
#  0.0055
# -0.0025
#  0.0176
#  0.0377
#  0.0028
# -0.0153
#  0.0047
# -0.0065
# -0.0159
# -0.0158
#  0.0054
# -0.0406
# -0.0328
# -0.0400
# -0.0313
# -0.0215
# -0.0336
# -0.0493
# -0.0241
# -0.0495
# -0.0131
# -0.0537
# -0.0461
# -0.0417
# -0.0537
# -0.0601
# -0.0039
# -0.0402
# -0.0448
# -0.0108
#  0.0412
#  0.0169
#  0.0369
#  0.1034
#  0.0820
#  0.0305
#  0.0667
#  0.0496
# -0.0105
# -0.0359
# -0.0091
# -0.0257
# -0.0055
# -0.0173
# -0.0198
# -0.0764
# -0.0239
#  0.0066
#  0.0038
#  0.0062
#  0.0014
#  0.0126
#  0.0146
#  0.0089
#  0.0080
#  0.0134
#  0.0165
#  0.0711
#  0.0287
#  0.0249
#  0.0861
#  0.0128
#  0.0365
#  0.0497
#  0.0415
#  0.0505
#  0.0699
#  0.0673
#  0.0549
#  0.0072
#  0.1057
#  0.0284
#  0.0616
#  0.0721
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0213
# -0.0217
#  0.0246
# -0.0078
# -0.0544
# -0.0202
# -0.0099
# -0.0219
# -0.0073
# -0.0109
# -0.0238
#  0.0050
#  0.0012
# -0.0872
# -0.0308
# -0.0122
# -0.0387
# -0.0010
#  0.0076
#  0.0206
#  0.0072
#  0.0237
# -0.0369
#  0.0223
# -0.0060
#  0.0145
#  0.0136
#  0.0061
#  0.0374
# -0.0074
# -0.0125
#  0.0612
# -0.0470
#  0.0294
#  0.0573
#  0.0124
# -0.0146
#  0.0165
#  0.0032
#  0.0731
#  0.0415
#  0.0881
#  0.0400
#  0.0580
#  0.0646
# -0.0020
#  0.0049
#  0.0073
#  0.0262
# -0.0244
#  0.0169
#  0.0116
#  0.0058
# -0.0031
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0013
#  0.0057
#  0.0070
# -0.0116
# -0.0090
#  0.0038
#  0.0011
# -0.0124
#  0.0000
# -0.0067
# -0.0040
# -0.0096
# -0.0008
#  0.0025
#  0.0002
#  0.0007
#  0.0053
# -0.0001
# -0.0324
# -0.0380
# -0.0232
# -0.0477
#  0.0243
# -0.0464
# -0.0323
# -0.0417
# -0.0482
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0172
# -0.0146
#  0.0187
# -0.0264
#  0.0427
#  0.0161
# -0.0237
# -0.0258
# -0.0339
# -0.0429
# -0.0287
# -0.0396
# -0.0437
# -0.0580
# -0.0392
# -0.0452
# -0.0299
# -0.0382
#  0.0099
#  0.0059
# -0.0026
#  0.0100
# -0.0853
# -0.0041
# -0.0018
#  0.0029
# -0.0191
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0278
# -0.0170
# -0.0163
# -0.0340
# -0.0922
# -0.0576
# -0.0274
# -0.0911
# -0.0586
#  0.0031
#  0.0011
#  0.0145
# -0.0157
# -0.0176
# -0.0024
# -0.0047
# -0.0142
# -0.0042
#  0.0019
#  0.0172
#  0.0396
#  0.0029
# -0.0286
#  0.0254
#  0.0105
# -0.0554
#  0.0069
#  0.0036
#  0.0029
#  0.0011
#  0.0033
#  0.0062
#  0.0045
#  0.0072
#  0.0046
#  0.0050
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
# -0.0000
# -0.0000
# -0.0000
#  0.0095
# -0.0329
# -0.0283
# -0.0104
# -0.0022
# -0.0431
# -0.0274
# -0.0558
# -0.0458
#  0.0169
#  0.0225
#  0.0230
#  0.0356
#  0.0688
#  0.0651
#  0.0257
#  0.0465
#  0.0473
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0116
#  0.0217
#  0.0064
# -0.0123
# -0.0018
# -0.0042
# -0.0076
#  0.0110
# -0.0083
# -0.0411
# -0.0132
# -0.0229
# -0.0341
# -0.0075
# -0.0393
# -0.0290
# -0.0410
# -0.0489
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0038
#  0.0029
# -0.0002
#  0.0040
#  0.0398
#  0.0025
#  0.0125
# -0.0009
#  0.0080
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0111
# -0.0001
# -0.0160
# -0.0184
# -0.0618
# -0.0490
# -0.0246
# -0.0065
# -0.0112
#  0.0166
# -0.0247
# -0.0106
# -0.0194
# -0.0204
#  0.0043
# -0.0075
# -0.0031
#  0.0026
#  0.0060
#  0.0436
#  0.0314
#  0.0128
# -0.0275
#  0.0435
#  0.0010
#  0.0032
#  0.0316
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0154
#  0.0190
#  0.0308
#  0.0765
#  0.0570
#  0.0585
#  0.0563
#  0.0927
#  0.0455
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0104
# -0.0177
#  0.0005
# -0.0103
# -0.0564
# -0.0233
#  0.0150
# -0.0131
#  0.0078
#  0.0142
#  0.0133
#  0.0291
# -0.0056
# -0.0168
# -0.0098
#  0.0180
#  0.0107
#  0.0144
# -0.0169
# -0.0258
# -0.0233
# -0.0320
# -0.0081
# -0.0416
# -0.0035
# -0.0140
# -0.0058
# -0.0077
# -0.0572
# -0.0431
# -0.0515
# -0.0840
# -0.0535
# -0.0072
# -0.0566
# -0.0166
# -0.0287
# -0.0248
# -0.0178
# -0.0331
#  0.0373
# -0.0531
# -0.0244
# -0.0417
# -0.0682
#  0.0074
#  0.0009
#  0.0085
#  0.0069
#  0.0201
# -0.0004
#  0.0051
#  0.0006
#  0.0071
# -0.0086
# -0.0124
#  0.0045
# -0.0417
#  0.0389
# -0.0354
# -0.0244
# -0.0608
# -0.0263
#  0.0075
#  0.0265
#  0.0107
#  0.0094
# -0.0015
#  0.0238
#  0.0296
#  0.0439
#  0.0311
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
# -0.0021
#  0.0114
#  0.0009
# -0.0145
# -0.0020
# -0.0293
# -0.0035
#  0.0064
#  0.0052
#  0.0262
#  0.0456
#  0.0340
#  0.0397
# -0.0141
#  0.0318
#  0.0254
#  0.0573
#  0.0269
#  0.0455
#  0.0081
#  0.0269
#  0.0284
# -0.0036
#  0.0051
#  0.0002
# -0.0229
#  0.0256
# -0.0067
# -0.0239
# -0.0068
#  0.0061
# -0.0053
#  0.0410
#  0.0353
#  0.0491
#  0.0355
#  0.0123
# -0.0081
#  0.0151
# -0.0132
# -0.0273
# -0.0283
#  0.0129
#  0.0048
#  0.0049
# -0.0242
# -0.1216
# -0.0657
# -0.0889
# -0.1147
# -0.1654
# -0.0281
# -0.1254
# -0.0576
# -0.0039
# -0.0203
# -0.0293
# -0.0417
# -0.0583
# -0.0304
# -0.0195
# -0.0077
# -0.0061
# -0.0269
#  0.0321
# -0.0168
#  0.0397
#  0.0035
#  0.0697
# -0.0196
#  0.0922
#  0.0288
#  0.0005
#  0.0084
#  0.0135
# -0.0105
#  0.0165
#  0.0070
# -0.0016
#  0.0036
#  0.0001
# -0.0077
#  0.0012
# -0.0098
# -0.0136
# -0.0490
# -0.0187
# -0.0162
# -0.0345
# -0.0192
# -0.0112
#  0.0065
# -0.0177
# -0.0237
# -0.0141
# -0.0308
#  0.0132
#  0.0248
#  0.0113
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0185
#  0.0444
#  0.0375
#  0.0541
#  0.0371
#  0.1456
#  0.0459
#  0.1122
#  0.0673
# -0.0308
# -0.0448
# -0.0470
# -0.0470
# -0.0666
# -0.0536
# -0.0108
# -0.0205
# -0.0338
# -0.0305
# -0.1123
# -0.0281
# -0.0725
# -0.0957
# -0.1231
#  0.0067
# -0.0961
# -0.0593
#  0.0020
# -0.0216
#  0.0033
# -0.0620
#  0.0125
# -0.0331
# -0.0194
# -0.1179
# -0.0156
# -0.0432
# -0.0675
# -0.0406
# -0.1162
# -0.0474
# -0.1429
# -0.0852
# -0.0997
# -0.0936
#  0.0094
#  0.0574
#  0.0573
#  0.0309
#  0.0780
#  0.1161
#  0.0269
#  0.0948
#  0.0728
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0127
# -0.0003
#  0.0167
#  0.0099
#  0.0078
#  0.0039
#  0.0096
# -0.0077
#  0.0082
# -0.0079
# -0.0067
# -0.0033
# -0.0077
# -0.0089
# -0.0039
#  0.0053
#  0.0081
#  0.0033
#  0.0334
#  0.0410
#  0.0317
#  0.0297
# -0.0329
#  0.0530
#  0.0383
#  0.0577
#  0.0522
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0429
#  0.0345
#  0.0170
#  0.0323
#  0.0094
#  0.0092
#  0.0223
#  0.0218
#  0.0016
#  0.0443
#  0.0355
#  0.0520
#  0.0455
#  0.0186
#  0.0269
#  0.0479
#  0.0420
#  0.0344
# -0.0120
# -0.0006
# -0.0112
# -0.0093
#  0.0804
# -0.0057
# -0.0150
# -0.0172
# -0.0115
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0157
#  0.0288
# -0.0146
#  0.0140
#  0.0288
# -0.0029
# -0.0345
#  0.0323
# -0.0075
#  0.0039
# -0.0098
# -0.0071
#  0.0077
#  0.0241
#  0.0211
#  0.0076
# -0.0001
#  0.0090
#  0.0084
#  0.0554
#  0.0206
#  0.0206
# -0.0042
#  0.0476
#  0.0253
#  0.0786
#  0.0338
#  0.0014
# -0.0008
# -0.0008
# -0.0028
# -0.0013
# -0.0023
# -0.0064
# -0.0062
# -0.0001
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0053
#  0.0022
#  0.0055
# -0.0252
# -0.0152
# -0.0137
# -0.0072
#  0.0192
#  0.0132
#  0.0167
#  0.0464
#  0.0461
#  0.0199
#  0.0202
#  0.0347
#  0.0247
#  0.0338
#  0.0314
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0107
#  0.0078
#  0.0138
#  0.0186
#  0.0201
#  0.0034
#  0.0261
#  0.0101
#  0.0072
#  0.0350
#  0.0506
#  0.0643
#  0.0362
# -0.0043
#  0.0732
#  0.0390
#  0.0753
#  0.0743
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0049
# -0.0204
#  0.0004
# -0.0040
# -0.0068
# -0.0074
# -0.0092
# -0.0216
# -0.0106
# -0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0231
#  0.0242
#  0.0113
#  0.0070
#  0.0154
#  0.0203
#  0.0186
#  0.0068
#  0.0226
# -0.0017
#  0.0328
# -0.0140
# -0.0066
#  0.0319
#  0.0802
# -0.0034
#  0.0710
# -0.0147
#  0.0230
#  0.0527
#  0.0323
#  0.0212
#  0.0378
#  0.0266
#  0.0456
#  0.0986
#  0.0444
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0261
# -0.0318
# -0.0227
# -0.0776
# -0.0548
# -0.0546
# -0.0518
# -0.0630
# -0.0448
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0148
# -0.0002
# -0.0167
# -0.0037
#  0.0600
#  0.0014
# -0.0167
#  0.0057
#  0.0032
# -0.0660
# -0.0535
#  0.0670
# -0.1157
#  0.0107
#  0.2417
# -0.0992
# -0.0674
#  0.1161
#  0.0667
#  0.0161
# -0.0360
#  0.1370
#  0.0233
# -0.0912
#  0.0810
#  0.0131
# -0.0280
#  0.0058
# -0.0192
# -0.0101
# -0.0287
# -0.0541
# -0.0137
# -0.0208
# -0.0360
# -0.0053
#  0.0327
# -0.0312
#  0.0068
#  0.0070
#  0.0013
#  0.0432
# -0.0035
# -0.0088
#  0.0353
#  0.0311
# -0.0010
# -0.0392
#  0.0560
# -0.0199
# -0.0662
#  0.0405
# -0.0018
# -0.0409
#  0.0179
#  0.0394
#  0.0566
# -0.0248
# -0.0809
#  0.0729
# -0.0137
#  0.0141
#  0.0536
#  0.0621
# -0.0171
# -0.0615
#  0.1750
#  0.0142
# -0.1825
#  0.1266
#  0.0073
# -0.0963
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0311
# -0.0061
# -0.0266
#  0.0547
#  0.0193
# -0.0762
#  0.0240
# -0.0009
# -0.0394
#  0.0433
#  0.0046
# -0.0080
# -0.0040
#  0.0130
# -0.0185
#  0.0247
#  0.0047
# -0.0207
# -0.0107
#  0.0115
#  0.0241
# -0.0060
#  0.0385
#  0.0118
#  0.0119
#  0.0401
#  0.0344
# -0.0119
#  0.0245
# -0.0377
# -0.0285
#  0.0082
#  0.0066
# -0.0283
#  0.0138
#  0.0394
# -0.0703
# -0.0417
#  0.1149
# -0.1429
#  0.0020
#  0.3418
# -0.1198
# -0.0848
#  0.1658
#  0.0143
# -0.0134
# -0.0044
#  0.0091
# -0.0313
#  0.0060
#  0.0124
#  0.0056
# -0.0045
#  0.0334
#  0.0380
#  0.0147
# -0.0105
# -0.0303
# -0.0697
#  0.0125
#  0.0001
# -0.0160
#  0.0280
# -0.0219
#  0.0120
#  0.0386
# -0.0429
#  0.0014
#  0.0306
#  0.0013
#  0.0228
#  0.0371
#  0.0121
# -0.0030
#  0.0654
#  0.0056
# -0.0406
#  0.0650
#  0.0095
# -0.0424
#  0.0153
# -0.0251
#  0.0062
#  0.0529
#  0.0253
#  0.0289
#  0.0745
# -0.0149
# -0.0364
#  0.1222
# -0.0227
# -0.1169
#  0.3147
#  0.0516
# -0.2935
#  0.2218
#  0.0145
# -0.1586
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0218
# -0.0490
# -0.0088
#  0.0111
# -0.0340
#  0.0184
#  0.0409
# -0.0413
#  0.0450
#  0.0011
# -0.0285
# -0.0030
#  0.0183
# -0.0378
# -0.0106
#  0.0109
# -0.0260
#  0.0109
# -0.0145
#  0.0030
# -0.0157
#  0.0378
#  0.0182
# -0.0164
#  0.0266
#  0.0039
# -0.0232
# -0.0047
#  0.0068
#  0.0280
# -0.0278
# -0.0818
#  0.0790
# -0.0376
#  0.0047
#  0.0626
# -0.0000
#  0.0080
#  0.0013
# -0.0161
#  0.0630
# -0.0081
# -0.0118
#  0.0148
# -0.0236
# -0.0195
# -0.0287
# -0.0251
#  0.0244
# -0.0298
# -0.0063
#  0.0252
#  0.0006
#  0.0099
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0321
#  0.0043
# -0.0234
#  0.0612
# -0.0241
# -0.0668
#  0.0572
#  0.0182
# -0.0470
# -0.0172
# -0.0053
#  0.0027
# -0.0173
# -0.0009
#  0.0107
# -0.0154
# -0.0051
#  0.0063
# -0.0052
#  0.0130
#  0.0152
# -0.0287
#  0.0333
# -0.0000
# -0.0028
#  0.0177
#  0.0159
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0091
# -0.0042
#  0.0085
#  0.0060
# -0.0074
# -0.0405
#  0.0099
# -0.0051
# -0.0210
# -0.0246
#  0.0019
#  0.0506
# -0.0288
#  0.0266
#  0.0622
# -0.0349
# -0.0162
#  0.0082
#  0.0184
#  0.0045
#  0.0158
#  0.0320
# -0.0338
#  0.0366
#  0.0136
# -0.0283
#  0.0270
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0310
# -0.0059
#  0.0330
#  0.0307
# -0.0250
#  0.0194
#  0.0500
# -0.0061
#  0.0194
#  0.0372
#  0.0069
# -0.0251
#  0.0658
# -0.0231
# -0.0622
#  0.0403
#  0.0018
# -0.0319
# -0.0031
# -0.0057
#  0.0056
#  0.0431
#  0.0227
#  0.0011
#  0.0326
# -0.0434
# -0.1030
#  0.0053
#  0.0062
#  0.0128
# -0.0034
#  0.0006
#  0.0092
# -0.0023
# -0.0017
#  0.0038
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0267
#  0.0022
#  0.0147
#  0.0806
#  0.0173
# -0.0130
#  0.0562
# -0.0285
# -0.0230
#  0.0067
#  0.0005
#  0.0261
#  0.0142
#  0.0168
#  0.0239
# -0.0129
#  0.0043
# -0.0058
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0056
#  0.0053
# -0.0099
#  0.0178
# -0.0019
# -0.0211
#  0.0031
#  0.0017
# -0.0171
# -0.0505
# -0.0439
#  0.0643
# -0.1135
# -0.0198
#  0.2172
# -0.0878
# -0.0620
#  0.1119
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0464
# -0.0328
#  0.0165
# -0.0793
# -0.0366
#  0.0927
# -0.0526
# -0.0293
#  0.0404
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0199
#  0.0087
#  0.0213
#  0.0149
# -0.0229
#  0.0442
#  0.0054
# -0.0362
#  0.0332
#  0.0181
#  0.0029
#  0.0577
#  0.0074
#  0.0263
#  0.0399
# -0.0104
# -0.0423
# -0.0314
# -0.0098
# -0.0195
# -0.0090
#  0.0180
# -0.0061
# -0.0112
#  0.0285
# -0.0286
# -0.0366
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0226
# -0.0212
# -0.0334
#  0.0435
#  0.1559
#  0.0718
#  0.0020
#  0.0612
# -0.0031
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0083
#  0.0242
#  0.0155
# -0.0217
# -0.0597
# -0.0211
# -0.0197
# -0.0182
#  0.0040
#  0.0106
#  0.0105
#  0.0379
# -0.0084
# -0.0084
#  0.0187
# -0.0053
# -0.0575
# -0.0118
# -0.0058
# -0.0045
# -0.0059
# -0.0145
# -0.0013
# -0.0025
#  0.0023
#  0.0276
#  0.0167
#  0.0251
#  0.0062
# -0.0066
#  0.0234
# -0.0091
#  0.0300
# -0.0113
#  0.0302
#  0.0297
# -0.0112
#  0.0242
#  0.0099
# -0.0049
# -0.0194
#  0.0007
# -0.0064
#  0.0249
#  0.0254
# -0.0152
# -0.0322
# -0.0327
#  0.0048
# -0.0100
# -0.0113
#  0.0211
#  0.0296
#  0.0122
# -0.0234
# -0.0348
# -0.0578
# -0.0092
# -0.0103
# -0.0665
#  0.0407
#  0.0870
# -0.0024
# -0.0025
# -0.0060
#  0.0008
# -0.0118
# -0.0056
#  0.0054
# -0.0008
#  0.0246
#  0.0200
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0048
#  0.0063
#  0.0255
#  0.0079
# -0.0068
#  0.0132
#  0.0186
# -0.0012
#  0.0009
#  0.0206
#  0.0148
#  0.0095
#  0.0224
#  0.0127
#  0.0032
# -0.0221
# -0.0223
# -0.0186
# -0.0238
# -0.0061
#  0.0006
# -0.0188
# -0.0323
# -0.0072
# -0.0336
# -0.0441
# -0.0223
#  0.0152
# -0.0267
#  0.0043
#  0.0198
# -0.0131
#  0.0094
#  0.0309
#  0.0026
# -0.0124
#  0.0179
#  0.0341
#  0.0512
# -0.0166
# -0.0103
#  0.0220
# -0.0163
# -0.0685
# -0.0112
#  0.0321
#  0.0355
#  0.0293
# -0.0074
# -0.0440
#  0.0278
#  0.0067
#  0.0085
#  0.0418
#  0.0122
#  0.0070
#  0.0037
#  0.0162
# -0.0100
# -0.0221
#  0.0142
# -0.0120
# -0.0109
# -0.0408
# -0.0215
#  0.0030
# -0.0335
# -0.1124
# -0.0227
# -0.0506
# -0.0623
# -0.0411
# -0.0240
# -0.0253
# -0.0255
# -0.0007
# -0.0083
# -0.0194
#  0.0196
#  0.0106
#  0.0042
# -0.0052
#  0.0168
#  0.0493
# -0.0084
# -0.0215
#  0.0422
# -0.0108
# -0.0134
#  0.0338
# -0.0055
#  0.0000
#  0.0124
# -0.0271
# -0.0097
#  0.0107
# -0.0167
#  0.0126
#  0.0184
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0180
#  0.0031
# -0.0017
#  0.0204
#  0.0495
#  0.0140
# -0.0083
#  0.0106
#  0.0047
# -0.0085
#  0.0012
#  0.0284
#  0.0136
# -0.0320
#  0.0380
# -0.0141
# -0.0112
# -0.0030
#  0.0009
# -0.0132
#  0.0036
# -0.0074
# -0.0403
#  0.0227
# -0.0139
# -0.0137
#  0.0041
# -0.0327
# -0.0709
# -0.0746
# -0.0237
# -0.0121
# -0.0765
#  0.0829
#  0.1222
#  0.0518
# -0.0124
# -0.0130
#  0.0004
# -0.0154
# -0.0293
# -0.0266
#  0.0053
# -0.0158
# -0.0053
# -0.0039
#  0.0092
#  0.0459
#  0.0152
# -0.0260
#  0.0036
#  0.0283
# -0.0030
# -0.0038
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0128
# -0.0343
# -0.0318
#  0.0000
# -0.0105
# -0.0148
#  0.0147
#  0.0304
#  0.0103
# -0.0043
# -0.0050
# -0.0070
# -0.0041
# -0.0102
# -0.0096
#  0.0012
# -0.0081
# -0.0083
#  0.0327
#  0.0237
#  0.0022
#  0.0032
# -0.0209
# -0.0112
# -0.0006
#  0.0093
#  0.0250
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0141
#  0.0208
#  0.0054
# -0.0185
# -0.0583
# -0.0063
# -0.0146
# -0.0274
# -0.0108
#  0.0069
#  0.0203
#  0.0251
#  0.0008
# -0.0167
#  0.0174
# -0.0206
# -0.0375
# -0.0010
# -0.0081
# -0.0254
# -0.0139
#  0.0032
#  0.0130
# -0.0077
#  0.0253
#  0.0377
# -0.0200
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0338
#  0.0475
#  0.0287
#  0.0627
#  0.0745
#  0.0470
#  0.0242
#  0.0639
#  0.0141
# -0.0113
# -0.0321
# -0.0334
# -0.0014
# -0.0122
# -0.0141
#  0.0200
#  0.0253
#  0.0108
#  0.0068
#  0.0114
#  0.0116
#  0.0145
#  0.0114
#  0.0046
# -0.0177
# -0.0308
# -0.0138
# -0.0050
# -0.0074
# -0.0081
# -0.0071
# -0.0095
# -0.0095
#  0.0002
#  0.0023
# -0.0023
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0094
#  0.0133
#  0.0106
# -0.0045
# -0.0050
#  0.0118
# -0.0259
# -0.0208
#  0.0077
#  0.0014
#  0.0328
#  0.0368
#  0.0166
# -0.0025
#  0.0198
#  0.0348
#  0.0203
#  0.0070
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0169
# -0.0298
# -0.0216
# -0.0065
# -0.0080
# -0.0042
#  0.0139
#  0.0047
# -0.0051
#  0.0179
#  0.0308
#  0.0337
# -0.0025
# -0.0042
#  0.0195
# -0.0213
# -0.0511
# -0.0056
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0197
# -0.0221
# -0.0103
#  0.0027
# -0.0078
# -0.0016
#  0.0244
#  0.0165
#  0.0204
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0034
# -0.0131
#  0.0192
# -0.0252
# -0.0166
#  0.0267
# -0.0332
# -0.0175
# -0.0031
# -0.0098
#  0.0226
#  0.0298
#  0.0235
#  0.0291
#  0.0247
#  0.0087
# -0.0111
#  0.0029
# -0.0047
# -0.0038
#  0.0095
#  0.0053
#  0.0030
#  0.0174
# -0.0125
# -0.0191
# -0.0021
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0104
#  0.0028
#  0.0297
# -0.0088
# -0.0121
# -0.0107
#  0.0108
#  0.0051
# -0.0130
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0005
# -0.0108
# -0.0401
# -0.0425
#  0.0616
# -0.0050
# -0.0054
#  0.0023
# -0.0288
#  0.0516
#  0.0473
#  0.0667
#  0.0679
# -0.0539
#  0.0381
#  0.0721
#  0.0220
# -0.0090
#  0.0311
# -0.0171
# -0.0002
#  0.0303
# -0.0115
# -0.0268
#  0.0264
#  0.0008
#  0.0141
# -0.0356
# -0.0332
# -0.0863
#  0.0014
#  0.1144
#  0.0139
# -0.0525
# -0.0146
# -0.0052
#  0.0066
#  0.0140
# -0.0274
# -0.0087
#  0.0120
#  0.0074
# -0.0092
#  0.0728
# -0.0183
# -0.0145
#  0.0142
#  0.0091
#  0.0049
#  0.0101
#  0.0096
# -0.0064
#  0.0178
#  0.0167
# -0.0414
# -0.1002
# -0.0615
# -0.0809
#  0.1466
#  0.0756
# -0.0741
# -0.0518
# -0.0063
#  0.0368
#  0.0083
# -0.0007
#  0.0522
# -0.0619
# -0.0171
#  0.0687
#  0.0163
#  0.0192
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0406
# -0.0000
#  0.0051
#  0.0115
# -0.1282
# -0.0302
#  0.0328
#  0.0253
#  0.0133
# -0.0227
#  0.0099
#  0.0032
#  0.0179
#  0.0467
#  0.0442
#  0.0159
# -0.0446
# -0.0051
# -0.0159
#  0.0103
# -0.0097
#  0.0114
#  0.0119
# -0.0311
#  0.0071
#  0.0609
# -0.0331
# -0.0220
# -0.0455
# -0.0310
# -0.0169
#  0.0429
#  0.0052
# -0.0458
# -0.0247
# -0.0273
#  0.0498
#  0.0205
#  0.0159
#  0.0796
# -0.0085
# -0.0223
#  0.0399
#  0.0061
# -0.0414
#  0.0078
# -0.0346
# -0.0141
#  0.0789
#  0.0761
#  0.0145
# -0.0270
# -0.0450
# -0.0022
#  0.0198
# -0.0187
#  0.0260
#  0.0166
# -0.0828
#  0.0533
#  0.0140
# -0.0321
#  0.0315
# -0.0059
# -0.0482
# -0.0221
# -0.0301
# -0.0113
#  0.0151
# -0.0039
#  0.0018
# -0.0790
# -0.0160
#  0.0082
#  0.0208
#  0.0045
#  0.0331
#  0.0334
# -0.0045
#  0.0056
#  0.0208
#  0.0271
#  0.0226
#  0.0157
#  0.0190
#  0.0331
# -0.0282
#  0.0518
#  0.0314
# -0.0510
#  0.0857
#  0.0133
#  0.0199
#  0.1029
# -0.1270
# -0.0373
#  0.1234
#  0.0118
#  0.0045
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0176
# -0.0268
# -0.0078
#  0.0109
#  0.0600
# -0.0676
# -0.0287
#  0.0192
#  0.0184
# -0.0061
# -0.0388
# -0.0119
#  0.0090
#  0.0271
# -0.0151
#  0.0273
#  0.0018
# -0.0253
#  0.0111
#  0.0096
#  0.0139
#  0.0523
# -0.0289
# -0.0025
#  0.0246
# -0.0223
# -0.0057
# -0.0183
# -0.0536
#  0.0079
# -0.0873
#  0.1630
#  0.0909
# -0.0193
#  0.0017
#  0.0336
#  0.0155
# -0.0729
# -0.0032
# -0.0151
# -0.0727
#  0.0470
#  0.0215
# -0.1157
# -0.0594
# -0.0174
# -0.0275
# -0.0268
# -0.0622
# -0.0975
# -0.0945
#  0.0153
#  0.0064
#  0.0437
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0350
#  0.0081
# -0.0055
# -0.0087
#  0.0219
#  0.0116
# -0.0102
#  0.0048
#  0.0175
# -0.0070
# -0.0064
# -0.0101
# -0.0086
# -0.0030
# -0.0062
# -0.0089
# -0.0049
# -0.0155
#  0.0046
#  0.0145
# -0.0164
# -0.0575
#  0.0888
#  0.0146
# -0.0195
#  0.0038
# -0.0025
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0006
# -0.0136
# -0.0134
#  0.0049
# -0.0127
#  0.0098
# -0.0137
# -0.0138
#  0.0086
#  0.0186
#  0.0274
#  0.0190
#  0.0266
# -0.0130
# -0.0002
#  0.0128
# -0.0044
# -0.0132
# -0.0022
# -0.0396
#  0.0015
#  0.0047
# -0.0233
# -0.0166
#  0.0024
# -0.0293
# -0.0131
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0152
# -0.0236
# -0.0149
#  0.0244
#  0.0546
#  0.0186
#  0.0157
# -0.0253
# -0.0023
# -0.0170
#  0.0065
#  0.0004
# -0.0111
#  0.0242
# -0.0087
# -0.0049
#  0.0165
#  0.0188
#  0.0441
# -0.0089
# -0.0039
#  0.0300
# -0.0041
#  0.0668
#  0.0170
# -0.0872
# -0.0457
# -0.0090
# -0.0070
# -0.0111
# -0.0165
# -0.0133
# -0.0111
# -0.0139
# -0.0145
# -0.0122
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0093
# -0.0028
# -0.0180
#  0.0201
# -0.0306
# -0.0543
# -0.0065
# -0.0211
#  0.0067
#  0.0203
#  0.0366
#  0.0098
#  0.0429
#  0.0032
#  0.0032
#  0.0229
#  0.0042
#  0.0085
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0173
#  0.0045
#  0.0082
#  0.0111
# -0.0142
#  0.0246
# -0.0022
# -0.0082
#  0.0121
#  0.0149
#  0.0021
# -0.0285
#  0.0289
#  0.0117
# -0.0106
#  0.0132
#  0.0058
# -0.0490
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0269
# -0.0050
#  0.0157
# -0.0431
#  0.0590
#  0.0652
# -0.0411
# -0.0035
#  0.0180
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0071
# -0.0114
#  0.0385
# -0.0401
# -0.0299
# -0.1350
# -0.0116
#  0.0507
# -0.0123
# -0.0042
#  0.0505
# -0.0346
#  0.0612
# -0.0645
# -0.0346
# -0.0135
# -0.0818
#  0.0908
# -0.0045
#  0.0070
#  0.0031
# -0.0138
# -0.0562
# -0.0244
# -0.0187
# -0.0389
# -0.0420
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0160
# -0.0076
# -0.0181
#  0.0119
# -0.0220
# -0.0382
#  0.0038
# -0.0175
# -0.0521
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0237
#  0.0156
# -0.0219
#  0.0156
#  0.1571
#  0.0010
# -0.0266
#  0.0366
# -0.0283
#  0.0054
#  0.0059
# -0.0101
#  0.0232
#  0.0385
# -0.0048
#  0.0089
#  0.0141
# -0.0047
#  0.0053
#  0.0116
#  0.0169
# -0.0126
# -0.0119
#  0.0050
# -0.0009
# -0.0012
#  0.0069
#  0.0051
# -0.0183
#  0.0115
#  0.0282
#  0.0073
#  0.0213
#  0.0042
# -0.0073
#  0.0222
# -0.0024
#  0.0118
#  0.0097
#  0.0197
#  0.0696
#  0.0213
#  0.0011
#  0.0092
# -0.0118
#  0.0065
#  0.0012
#  0.0079
#  0.0065
#  0.0065
#  0.0108
# -0.0008
# -0.0056
#  0.0073
#  0.0060
# -0.0004
#  0.0091
# -0.0110
# -0.0639
#  0.0112
#  0.0076
#  0.0045
#  0.0435
#  0.0085
#  0.0071
#  0.0205
# -0.0050
# -0.0039
#  0.0035
#  0.0038
# -0.0095
# -0.0008
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0058
# -0.0010
# -0.0049
# -0.0119
#  0.0063
# -0.0229
# -0.0160
# -0.0217
# -0.0196
# -0.0001
# -0.0204
# -0.0101
#  0.0129
#  0.0339
#  0.0000
# -0.0148
# -0.0124
#  0.0163
#  0.0015
# -0.0049
# -0.0060
#  0.0127
#  0.0439
# -0.0094
# -0.0145
# -0.0040
# -0.0067
# -0.0133
# -0.0024
#  0.0107
# -0.0092
#  0.0058
#  0.0192
# -0.0129
#  0.0019
#  0.0273
#  0.0012
#  0.0078
# -0.0079
#  0.0134
#  0.0233
# -0.0082
#  0.0036
#  0.0218
#  0.0074
#  0.0048
#  0.0191
#  0.0001
#  0.0266
#  0.0237
#  0.0092
#  0.0058
#  0.0338
#  0.0190
# -0.0179
#  0.0052
# -0.0154
#  0.0244
#  0.1240
#  0.0111
# -0.0083
#  0.0201
# -0.0337
# -0.0033
# -0.0267
#  0.0110
#  0.0097
#  0.0145
#  0.0130
#  0.0167
# -0.0179
#  0.0124
#  0.0037
#  0.0008
#  0.0097
# -0.0102
#  0.0010
#  0.0032
# -0.0151
# -0.0128
# -0.0078
# -0.0046
#  0.0128
# -0.0114
#  0.0233
#  0.0717
# -0.0129
# -0.0009
#  0.0082
# -0.0271
#  0.0074
#  0.0127
#  0.0291
# -0.0067
#  0.0056
#  0.0140
#  0.0065
# -0.0058
#  0.0053
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0296
# -0.0164
#  0.0113
#  0.0196
#  0.0137
#  0.0115
#  0.0101
# -0.0089
#  0.0070
#  0.0010
# -0.0233
#  0.0002
#  0.0094
# -0.0011
#  0.0055
#  0.0000
# -0.0241
#  0.0137
# -0.0213
# -0.0055
# -0.0072
# -0.0181
# -0.0192
# -0.0172
# -0.0144
# -0.0057
# -0.0014
#  0.0098
# -0.0194
# -0.0037
# -0.0107
# -0.0978
# -0.0262
#  0.0074
# -0.0252
#  0.0028
# -0.0084
#  0.0208
# -0.0206
#  0.0354
#  0.1252
#  0.0122
# -0.0048
#  0.0296
# -0.0223
#  0.0091
#  0.0032
#  0.0233
#  0.0120
#  0.0101
#  0.0156
#  0.0065
# -0.0107
# -0.0065
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0044
# -0.0107
#  0.0008
# -0.0020
# -0.0010
#  0.0077
# -0.0086
# -0.0106
#  0.0035
# -0.0031
# -0.0026
# -0.0064
#  0.0031
#  0.0017
# -0.0007
#  0.0036
#  0.0013
# -0.0007
#  0.0199
#  0.0150
#  0.0199
# -0.0070
# -0.0025
# -0.0285
#  0.0217
#  0.0151
# -0.0154
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
# -0.0000
#  0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0000
# -0.0027
# -0.0133
#  0.0160
#  0.0210
#  0.0579
#  0.0206
#  0.0097
# -0.0025
# -0.0087
# -0.0012
#  0.0080
# -0.0082
#  0.0122
#  0.0311
# -0.0069
#  0.0049
#  0.0132
#  0.0053
# -0.0089
# -0.0077
# -0.0223
#  0.0088
#  0.0018
#  0.0069
# -0.0150
# -0.0166
# -0.0144
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0211
#  0.0120
# -0.0012
#  0.0384
#  0.0631
#  0.0308
#  0.0037
#  0.0281
#  0.0271
# -0.0088
# -0.0130
# -0.0026
# -0.0099
# -0.0053
#  0.0110
# -0.0103
# -0.0153
# -0.0058
#  0.0023
# -0.0076
# -0.0009
# ...
#  0.0009
#  0.0030
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0094
#  0.0143
#  0.0171
#  0.0001
# -0.0277
#  0.0119
#  0.0198
# -0.0004
#  0.0344
#  0.0053
#  0.0005
#  0.0073
#  0.0109
#  0.0033
# -0.0042
# -0.0089
#  0.0005
# -0.0022
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0019
# -0.0113
#  0.0036
#  0.0013
# -0.0122
# -0.0045
#  0.0032
# -0.0036
#  0.0131
#  0.0276
#  0.0292
#  0.0197
#  0.0511
#  0.0311
#  0.0443
#  0.0212
#  0.0374
#  0.0285
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0399
#  0.0415
#  0.0551
#  0.0406
#  0.0332
#  0.0572
#  0.0430
#  0.0543
#  0.0512
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0118
# -0.0138
# -0.0071
#  0.0116
#  0.0107
#  0.0055
# -0.0010
# -0.0300
# -0.0269
# -0.0275
#  0.0294
#  0.0191
#  0.0355
# -0.0117
#  0.0031
# -0.0105
# -0.0122
# -0.0158
# -0.0087
# -0.0242
# -0.0176
# -0.0007
#  0.0148
# -0.0201
#  0.0120
#  0.0184
#  0.0082
#  0.0000
# -0.0000
#  0.0000
# -0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0286
#  0.0116
#  0.0352
# -0.0191
# -0.0175
#  0.0243
# -0.0079
#  0.0133
#  0.0241
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0018
# -0.0078
# -0.0091
# -0.0132
# -0.0358
# -0.0211
#  0.0044
# -0.0071
#  0.0058
#  0.0861
#  0.2410
#  0.1866
# -0.0320
#  0.0494
# -0.0138
# -0.1126
# -0.2583
# -0.1903
# -0.0087
# -0.0318
# -0.0162
# -0.0276
# -0.0221
# -0.0128
#  0.0468
#  0.1523
#  0.0843
#  0.0243
# -0.0085
# -0.0140
# -0.0097
# -0.0460
#  0.0102
# -0.0063
# -0.0070
#  0.0208
# -0.0117
#  0.0177
# -0.0061
# -0.0326
# -0.0590
# -0.0496
# -0.0042
#  0.0179
#  0.0475
# -0.0609
# -0.1004
# -0.0723
# -0.0242
# -0.0308
# -0.0228
#  0.0733
#  0.1346
#  0.0855
#  0.0237
# -0.0008
#  0.0118
# -0.0131
# -0.0659
# -0.0397
#  0.0494
#  0.0878
#  0.0113
# -0.0186
# -0.0751
# -0.0611
# -0.0542
# -0.0342
# -0.0594
#  0.0555
#  0.2147
#  0.1302
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0266
# -0.0146
#  0.0074
# -0.0161
# -0.0049
# -0.0414
#  0.0129
#  0.0486
# -0.0208
#  0.0240
#  0.0122
#  0.0094
#  0.0000
#  0.0197
#  0.0030
# -0.0233
#  0.0051
# -0.0082
#  0.0177
#  0.0368
#  0.0366
# -0.0064
#  0.0078
# -0.0123
#  0.0140
# -0.0122
# -0.0063
# -0.0454
# -0.0430
#  0.0554
#  0.0070
#  0.0087
#  0.0191
#  0.0768
#  0.0354
# -0.0520
#  0.1519
#  0.3479
#  0.2627
# -0.0250
#  0.0431
#  0.0034
# -0.1296
# -0.3447
# -0.2161
#  0.0291
#  0.0440
#  0.0507
#  0.0085
# -0.0023
#  0.0367
#  0.0122
#  0.0184
#  0.0060
#  0.0082
#  0.0103
# -0.0136
#  0.0129
# -0.0187
# -0.0302
#  0.0070
# -0.0096
# -0.0104
#  0.0471
#  0.0312
#  0.0341
#  0.0160
# -0.0108
# -0.0342
#  0.0180
#  0.0175
#  0.0106
# -0.0411
# -0.0694
# -0.0599
# -0.0104
# -0.0346
# -0.0265
#  0.0433
#  0.0836
#  0.0754
#  0.0003
#  0.0105
#  0.0140
# -0.0032
# -0.0169
# -0.0194
#  0.0072
# -0.0155
# -0.0061
# -0.0438
# -0.1132
# -0.0844
# -0.0890
# -0.0403
# -0.0922
#  0.0933
#  0.3323
#  0.1802
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0082
#  0.0124
# -0.0237
# -0.0090
# -0.0282
#  0.0095
#  0.0058
# -0.0156
#  0.0476
# -0.0021
# -0.0334
# -0.0017
#  0.0231
# -0.0054
# -0.0071
# -0.0058
# -0.0046
# -0.0198
# -0.0170
# -0.0522
# -0.0022
#  0.0302
#  0.0171
#  0.0271
# -0.0102
#  0.0264
# -0.0022
#  0.0047
# -0.0177
# -0.0516
# -0.0440
# -0.0873
# -0.0132
#  0.0110
#  0.0911
#  0.1207
# -0.0083
#  0.0535
# -0.0098
# -0.0287
#  0.0294
# -0.0545
# -0.0123
#  0.0290
# -0.0064
# -0.0116
#  0.0075
#  0.0176
# -0.0236
#  0.0717
#  0.0342
# -0.0241
#  0.0895
#  0.0004
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0415
# -0.1115
# -0.0738
# -0.0253
# -0.0508
# -0.0315
#  0.0549
#  0.1315
#  0.0919
#  0.0008
#  0.0058
#  0.0068
# -0.0089
# -0.0150
# -0.0128
# -0.0166
# -0.0296
# -0.0226
#  0.0219
#  0.0276
#  0.0163
# -0.0405
# -0.0492
# -0.0260
#  0.0152
# -0.0134
#  0.0053
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0016
#  0.0248
#  0.0269
# -0.0125
# -0.0428
# -0.0075
# -0.0083
# -0.0255
# -0.0145
#  0.0548
#  0.0776
#  0.0703
#  0.0080
#  0.0186
# -0.0013
# -0.0434
# -0.0834
# -0.0549
#  0.0245
#  0.0020
#  0.0093
# -0.0007
#  0.0209
#  0.0220
# -0.0201
#  0.0397
#  0.0065
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0219
#  0.0203
#  0.0115
# -0.0190
# -0.0109
# -0.0208
# -0.0211
# -0.0056
# -0.0321
# -0.0288
# -0.0980
# -0.0911
# -0.0173
# -0.0259
# -0.0038
#  0.0358
#  0.1267
#  0.1426
#  0.0200
# -0.0187
# -0.0033
#  0.0077
#  0.0240
# -0.0304
#  0.0088
# -0.0402
# -0.0062
# -0.0030
#  0.0041
#  0.0072
# -0.0012
# -0.0009
# -0.0010
#  0.0038
# -0.0029
# -0.0057
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0316
#  0.0262
#  0.0138
#  0.0030
# -0.0097
# -0.0053
#  0.0043
#  0.0174
#  0.0170
#  0.0262
#  0.0142
#  0.0262
#  0.0319
#  0.0018
# -0.0014
# -0.0101
# -0.0423
# -0.0328
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0387
# -0.0416
# -0.0086
# -0.0050
#  0.0072
# -0.0074
#  0.0345
#  0.0640
# -0.0090
#  0.1082
#  0.2260
#  0.1550
# -0.0134
#  0.0213
# -0.0104
# -0.0890
# -0.2362
# -0.1345
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0007
#  0.0159
#  0.0209
#  0.0091
# -0.0223
#  0.0006
# -0.0017
# -0.0610
# -0.0363
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0486
#  0.0340
#  0.0327
#  0.0233
# -0.0130
#  0.0346
# -0.0558
# -0.0731
#  0.0191
#  0.0172
#  0.0263
#  0.0485
# -0.0379
# -0.0151
#  0.0215
# -0.0325
# -0.0187
# -0.0202
#  0.0152
# -0.0595
# -0.0202
#  0.0402
# -0.0348
#  0.0101
#  0.0045
# -0.0616
# -0.0050
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0116
#  0.0214
#  0.0146
# -0.0440
# -0.0178
#  0.0195
# -0.0272
# -0.0010
#  0.0438
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0079
#  0.0144
#  0.0101
#  0.0150
# -0.0533
#  0.0260
#  0.0440
#  0.0224
#  0.0298
#  0.0861
# -0.0287
# -0.0500
#  0.2068
# -0.0255
# -0.1680
#  0.1508
# -0.0432
# -0.1016
# -0.0064
# -0.0236
#  0.0394
# -0.0212
#  0.0089
#  0.1083
# -0.0019
# -0.0249
#  0.0209
# -0.0074
# -0.0116
# -0.0012
# -0.0076
# -0.0464
# -0.0284
# -0.0124
# -0.0397
# -0.0158
#  0.0246
#  0.0048
#  0.0290
#  0.0415
# -0.0270
#  0.0435
#  0.0635
# -0.0292
#  0.0156
# -0.0417
# -0.0121
#  0.0221
# -0.0708
#  0.0205
#  0.0710
# -0.0385
#  0.0093
#  0.0394
# -0.0059
# -0.0478
#  0.0058
# -0.0012
#  0.0170
#  0.0571
# -0.0368
# -0.0430
#  0.0410
#  0.0097
# -0.0464
#  0.0109
# -0.0218
# -0.0075
#  0.1421
# -0.0210
# -0.0576
#  0.0554
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0017
# -0.0075
# -0.0085
#  0.0324
#  0.0281
#  0.0430
#  0.0268
# -0.0527
# -0.0134
#  0.0039
# -0.0191
# -0.0024
#  0.0268
#  0.0019
# -0.0207
# -0.0095
# -0.0166
#  0.0259
#  0.0223
#  0.0048
# -0.0364
#  0.0198
# -0.0217
# -0.0048
#  0.0317
# -0.0440
# -0.0287
# -0.0339
# -0.0530
# -0.0150
# -0.0072
# -0.0554
# -0.0602
# -0.0379
# -0.0493
# -0.0330
#  0.1310
# -0.0456
# -0.0783
#  0.2847
# -0.0289
# -0.2379
#  0.1918
# -0.0478
# -0.1464
#  0.0094
# -0.0122
#  0.0100
#  0.0364
# -0.0136
# -0.0213
# -0.0138
# -0.0343
#  0.0065
# -0.0160
#  0.0091
# -0.0105
#  0.0281
#  0.1019
#  0.0212
# -0.0077
#  0.0539
#  0.0013
# -0.0111
# -0.0249
#  0.0316
# -0.0056
# -0.0380
# -0.0156
#  0.0177
# -0.0632
# -0.0031
# -0.0357
# -0.0098
# -0.0038
# -0.0790
#  0.0088
#  0.0725
# -0.0572
#  0.0157
#  0.0576
#  0.0340
# -0.0018
#  0.0009
#  0.0394
# -0.0540
#  0.0136
#  0.0211
# -0.0154
#  0.0438
#  0.0010
# -0.0677
#  0.0286
# -0.0373
# -0.0048
#  0.2285
# -0.0234
# -0.0865
#  0.0798
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0034
#  0.0310
#  0.0282
# -0.0077
# -0.0447
#  0.0188
#  0.0290
#  0.0086
# -0.0041
# -0.0300
# -0.0249
# -0.0152
# -0.0039
#  0.0027
# -0.0083
#  0.0125
# -0.0064
# -0.0115
#  0.0039
#  0.0014
# -0.0058
#  0.0184
#  0.0203
# -0.0053
#  0.0191
# -0.0073
#  0.0053
# -0.0175
# -0.0317
#  0.0126
# -0.0143
#  0.0271
#  0.1278
# -0.0476
# -0.0279
#  0.0315
#  0.0270
#  0.0175
# -0.0019
#  0.0179
# -0.0104
#  0.0455
# -0.0020
# -0.0149
#  0.0353
#  0.0011
#  0.0011
#  0.0408
#  0.0067
# -0.0076
# -0.0124
# -0.0074
# -0.0549
# -0.0160
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0493
# -0.0231
#  0.0129
# -0.0941
#  0.0164
#  0.0889
# -0.0537
#  0.0128
#  0.0576
#  0.0159
#  0.0023
# -0.0010
#  0.0197
#  0.0001
# -0.0098
#  0.0130
#  0.0006
# -0.0042
#  0.0216
#  0.0409
# -0.0136
#  0.0147
# -0.0285
# -0.0039
#  0.0048
#  0.0308
# -0.0182
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
# -0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0135
# -0.0273
#  0.0073
#  0.0189
# -0.0259
# -0.0152
#  0.0152
#  0.0123
# -0.0366
#  0.0519
# -0.0043
# -0.0223
#  0.0746
#  0.0052
# -0.0454
#  0.0880
#  0.0339
# -0.0047
# -0.0081
# -0.0298
#  0.0066
# -0.0285
#  0.0038
#  0.0420
# -0.0174
# -0.0238
#  0.0359
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0498
#  0.0101
# -0.0024
#  0.0077
# -0.0285
#  0.0048
#  0.0092
# -0.0305
#  0.0470
# -0.0480
# -0.0264
#  0.0197
# -0.0831
#  0.0135
#  0.0833
# -0.0449
#  0.0067
#  0.0524
# -0.0185
# -0.0315
# -0.0101
#  0.0420
# -0.0619
# -0.0429
# -0.0162
#  0.0464
#  0.1176
# -0.0020
# -0.0068
# -0.0081
#  0.0061
#  0.0009
# -0.0069
# -0.0015
# -0.0021
# -0.0065
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0328
# -0.0240
#  0.0049
#  0.0138
# -0.0118
#  0.0178
# -0.0104
#  0.0042
#  0.0095
# -0.0067
# -0.0048
#  0.0269
#  0.0174
# -0.0073
# -0.0021
#  0.0540
#  0.0303
#  0.0025
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0022
# -0.0199
# -0.0059
# -0.0162
# -0.0049
#  0.0159
# -0.0047
# -0.0065
#  0.0205
#  0.0928
# -0.0325
# -0.0529
#  0.2010
# -0.0391
# -0.1754
#  0.1256
# -0.0445
# -0.0881
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0084
#  0.0082
# -0.0076
#  0.0235
#  0.0020
# -0.0243
#  0.0087
#  0.0105
#  0.0125
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0281
# -0.0485
# -0.0350
#  0.0533
#  0.0366
#  0.0404
#  0.0047
# -0.0396
# -0.0233
#  0.0318
# -0.0763
#  0.0425
#  0.0449
# -0.0274
# -0.0184
#  0.0239
#  0.0839
# -0.0364
# -0.0139
# -0.0307
# -0.0208
# -0.0016
# -0.0005
#  0.0002
#  0.0008
#  0.0049
#  0.0319
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0384
# -0.0294
#  0.0056
# -0.0094
# -0.1456
# -0.0414
#  0.0335
# -0.0248
#  0.0351
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0039
# -0.0107
# -0.0165
#  0.0054
#  0.0605
# -0.0053
# -0.0001
# -0.0073
# -0.0013
#  0.0509
#  0.0566
#  0.0485
#  0.0853
# -0.0036
#  0.1187
#  0.0739
#  0.1225
#  0.1230
# -0.0229
# -0.0122
# -0.0222
# -0.0234
# -0.0154
# -0.0343
# -0.0360
# -0.0368
# -0.0383
# -0.0260
# -0.0793
# -0.0465
# -0.0366
# -0.0517
# -0.0905
# -0.0065
# -0.0768
# -0.0379
# -0.0140
# -0.0180
#  0.0189
# -0.0081
#  0.0095
#  0.0283
#  0.0212
# -0.0103
#  0.0009
# -0.0038
#  0.0117
# -0.0079
#  0.0045
#  0.0661
# -0.0073
# -0.0125
# -0.0143
# -0.0189
# -0.0066
# -0.0229
# -0.0332
# -0.0735
#  0.0515
# -0.1637
# -0.0304
# -0.0876
# -0.0966
# -0.0365
# -0.0091
# -0.0143
# -0.0202
# -0.0068
# -0.0085
# -0.0355
# -0.0138
# -0.0224
#  0.0000
# -0.0000
#  0.0000
# -0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0067
# -0.0150
# -0.0175
#  0.0152
# -0.0277
# -0.0107
# -0.0046
# -0.0094
# -0.0018
# -0.0111
# -0.0042
# -0.0141
# -0.0077
# -0.0473
# -0.0558
# -0.0363
# -0.0226
#  0.0180
#  0.0196
#  0.0139
# -0.0112
# -0.0087
#  0.0031
#  0.0091
#  0.0016
# -0.0120
#  0.0302
# -0.0028
#  0.0467
#  0.0173
#  0.0160
#  0.0224
#  0.0080
# -0.0126
# -0.0124
# -0.0019
#  0.0402
#  0.0279
#  0.0345
#  0.0463
# -0.0271
#  0.0526
#  0.0472
#  0.0402
#  0.0503
# -0.0117
# -0.0449
# -0.0299
#  0.0001
# -0.0405
# -0.0615
#  0.0086
# -0.0312
# -0.0525
#  0.0166
#  0.0152
#  0.0200
#  0.0726
#  0.0598
#  0.0414
#  0.0255
#  0.0504
#  0.0395
# -0.0172
# -0.0526
#  0.0080
# -0.0202
# -0.0155
# -0.0274
# -0.0012
# -0.0873
# -0.0369
# -0.0148
# -0.0110
# -0.0134
# -0.0262
#  0.0450
# -0.0042
# -0.0123
#  0.0061
# -0.0115
#  0.0152
#  0.0032
#  0.0264
#  0.0197
#  0.0234
#  0.0610
#  0.0165
#  0.0197
#  0.0149
# -0.0518
# -0.0056
# -0.0348
# -0.0226
# -0.0200
# -0.0037
# -0.0564
# -0.0102
# -0.0214
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0017
# -0.0087
# -0.0359
# -0.0195
# -0.1004
# -0.0166
#  0.0106
# -0.0728
# -0.0404
#  0.0046
# -0.0244
# -0.0108
# -0.0014
# -0.0813
# -0.0296
# -0.0050
# -0.0385
# -0.0072
# -0.0051
# -0.0148
# -0.0135
# -0.0041
# -0.0721
# -0.0026
# -0.0213
#  0.0230
#  0.0193
#  0.0095
#  0.0379
#  0.0158
# -0.0249
#  0.0872
# -0.0171
# -0.0173
#  0.0437
# -0.0081
#  0.0097
#  0.0135
# -0.0051
#  0.0555
#  0.0476
#  0.0400
#  0.0319
#  0.0923
#  0.0480
#  0.0075
#  0.0495
#  0.0182
#  0.0168
# -0.0320
#  0.0416
#  0.0042
# -0.0067
#  0.0032
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0032
#  0.0019
#  0.0067
# -0.0065
#  0.0814
# -0.0039
#  0.0020
# -0.0019
# -0.0040
# -0.0085
# -0.0131
# -0.0051
# -0.0054
# -0.0077
#  0.0016
# -0.0025
#  0.0052
#  0.0069
# -0.0307
# -0.0212
# -0.0250
# -0.0522
#  0.0497
# -0.0692
# -0.0270
# -0.0382
# -0.0576
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0199
# -0.0095
#  0.0280
# -0.0051
#  0.0194
# -0.0244
#  0.0163
# -0.0372
# -0.0569
#  0.0276
#  0.0343
#  0.0428
#  0.0367
#  0.0220
#  0.0441
#  0.0428
#  0.0805
#  0.0756
#  0.0069
# -0.0055
#  0.0120
#  0.0070
# -0.0622
#  0.0244
#  0.0187
#  0.0125
#  0.0211
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0081
# -0.0484
# -0.0149
# -0.0571
# -0.0797
# -0.0635
# -0.0232
# -0.1092
# -0.0583
# -0.0030
#  0.0011
#  0.0213
# -0.0340
#  0.0520
#  0.0341
# -0.0113
# -0.0157
#  0.0004
# -0.0059
#  0.0165
#  0.0065
# -0.0047
# -0.0634
#  0.0112
# -0.0012
#  0.0574
#  0.0146
#  0.0004
# -0.0012
#  0.0013
# -0.0040
# -0.0048
#  0.0008
#  0.0017
#  0.0009
#  0.0039
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0416
# -0.0462
# -0.0254
# -0.0476
# -0.0724
# -0.0556
# -0.0224
# -0.0661
# -0.0287
#  0.0190
#  0.0240
#  0.0284
#  0.0316
#  0.0457
#  0.0459
#  0.0044
#  0.0424
#  0.0509
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0080
#  0.0122
#  0.0108
#  0.0150
#  0.0195
# -0.0217
# -0.0039
#  0.0028
# -0.0067
#  0.0223
#  0.0253
#  0.0147
#  0.0173
# -0.0043
#  0.0107
#  0.0160
# -0.0000
#  0.0027
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0096
# -0.0034
#  0.0074
# -0.0024
#  0.0005
# -0.0041
#  0.0037
# -0.0028
#  0.0046
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0120
# -0.0030
# -0.0246
#  0.0255
# -0.0339
#  0.0344
# -0.0000
# -0.0154
#  0.0126
# -0.0196
#  0.0248
#  0.0163
#  0.0445
# -0.0270
# -0.0077
#  0.0173
# -0.0039
#  0.0040
#  0.0003
#  0.0047
# -0.0116
#  0.0085
# -0.0055
#  0.0219
#  0.0084
#  0.0536
#  0.0454
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
# -0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
#  0.0000
# -0.0316
#  0.0356
#  0.0333
#  0.0141
#  0.0487
#  0.1182
#  0.0280
#  0.0761
#  0.0632
# [ torch.HalfTensor{9216} ]
# [2023-07-27 08:47:29,525] [INFO] [launch.py:178:sigkill_handler] Killing subprocess 8872
# [2023-07-27 08:47:29,526] [INFO] [launch.py:178:sigkill_handler] Killing subprocess 8873
# [2023-07-27 08:47:29,526] [INFO] [launch.py:178:sigkill_handler] Killing subprocess 8874
# [2023-07-27 08:47:29,526] [INFO] [launch.py:178:sigkill_handler] Killing subprocess 8875
# [2023-07-27 08:47:29,526] [ERROR] [launch.py:184:sigkill_handler] ['/opt/conda/bin/python3.8', '-u', '/dli/code/moe/large_model_deepspeed.py', '--local_rank=3', '--deepspeed', '--deepspeed_config', '/dli/code/moe/ds_config_stage_3.json', '--profile-execution=True', '--profile-name=zero_resnet152_stage3'] exits with return code = 1

# %% [markdown]
# Execute the next cell to create a link to Tensorboard in your browser.

# %%
# %%js
# const href = window.location.hostname +'/tensorboard/';
# let a = document.createElement('a');
# let link = document.createTextNode('Open Tensorboard!');
# a.appendChild(link);
# a.href = "http://" + href;
# a.style.color = "navy"
# a.target = "_blank"
# element.append(a);

# %% [markdown]
# ### Exercise: ZeRO Stage 1
#
# Compare ZeRO Stage 1 execution time and GPU/CPU memory to no ZeRO and ZeRO Stage 3 + Offload. We have already prepared the DeepSpeed configuration file. Let's have a look:

# %%
# Show DeepSpeed config file for Zero stage 1 
# !cat /dli/code/moe/ds_config_stage_1.json
# Out:
# {
#   "train_batch_size": 512,
#   "steps_per_print": 2000,
#   "optimizer": {
#     "type": "Adam",
#     "params": {
#       "lr": 0.001,
#       "betas": [
#         0.8,
#         0.999
#       ],
#       "eps": 1e-8,
#       "weight_decay": 3e-7
#     }
#   },
#   "scheduler": {
#     "type": "WarmupLR",
#     "params": {
#       "warmup_min_lr": 0,
#       "warmup_max_lr": 0.001,
#       "warmup_num_steps": 1000
#     }
#   },
#   "gradient_clipping": 1.0,
#   "prescale_gradients": false,
#   "fp16": {
#       "enabled": true,
#       "fp16_master_weights_and_grads": false,
#       "loss_scale": 0,
#       "loss_scale_window": 500,
#       "hysteresis": 2,
#       "min_loss_scale": 1,
#       "initial_scale_power": 15
#   },
#   "wall_clock_breakdown": false,
#   "activation_checkpointing": {
#       "partition_activations": false,
#       "cpu_checkpointing": false,
#       "contiguous_memory_optimization": false,
#       "number_checkpoints": 24,
#       "synchronize_checkpoint_boundary": false,
#       "profile": false
#     },
#   "zero_optimization": {
#       "stage": 1,
#       "allgather_partitions": true,
#       "reduce_scatter": true,
#       "allgather_bucket_size": 50000000,
#       "reduce_bucket_size": 50000000,
#       "overlap_comm": true,
#       "contiguous_gradients": true,
#       "cpu_offload": false
#   }
# }

# %% [markdown]
# Execute the next cell to run the *resnet152* model training on the CIFAR-10 dataset with ZeRO Stage1. Replace the `FIXME` with the corresponding arguments. If you get stuck, you can look at the [solution](solutions/ex5.2.4.ipynb).

# %%
# !deepspeed --num_gpus=4 /dli/code/moe/large_model_deepspeed.py \
    --deepspeed \
    --deepspeed_config /dli/code/moe/ds_config_stage_1.json \
    --profile-execution=True \
    --profile-name='zero_resnet512_stage1'
# Out:
# [2023-07-27 08:47:32,429] [WARNING] [runner.py:159:fetch_hostfile] Unable to find hostfile, will proceed with training with local resources only.
# [2023-07-27 08:47:32,612] [INFO] [runner.py:457:main] cmd = /opt/conda/bin/python3.8 -u -m deepspeed.launcher.launch --world_info=eyJsb2NhbGhvc3QiOiBbMCwgMSwgMiwgM119 --master_addr=127.0.0.1 --master_port=29500 /dli/code/moe/large_model_deepspeed.py --deepspeed --deepspeed_config /dli/code/moe/ds_config_stage_1.json --profile-execution=True --profile-name=zero_resnet512_stage1
# [2023-07-27 08:47:33,638] [INFO] [launch.py:96:main] 0 NCCL_P2P_DISABLE=1
# [2023-07-27 08:47:33,639] [INFO] [launch.py:96:main] 0 NCCL_VERSION=2.11.4
# [2023-07-27 08:47:33,639] [INFO] [launch.py:103:main] WORLD INFO DICT: {'localhost': [0, 1, 2, 3]}
# [2023-07-27 08:47:33,639] [INFO] [launch.py:109:main] nnodes=1, num_local_procs=4, node_rank=0
# [2023-07-27 08:47:33,639] [INFO] [launch.py:122:main] global_rank_mapping=defaultdict(<class 'list'>, {'localhost': [0, 1, 2, 3]})
# [2023-07-27 08:47:33,639] [INFO] [launch.py:123:main] dist_world_size=4
# [2023-07-27 08:47:33,639] [INFO] [launch.py:125:main] Setting CUDA_VISIBLE_DEVICES=0,1,2,3
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# Using cache found in /home/admin/.cache/torch/hub/pytorch_vision_v0.10.0
# Using cache found in /home/admin/.cache/torch/hub/pytorch_vision_v0.10.0
# Using cache found in /home/admin/.cache/torch/hub/pytorch_vision_v0.10.0
# Using cache found in /home/admin/.cache/torch/hub/pytorch_vision_v0.10.0
# [2023-07-27 08:47:36,873] [INFO] [logging.py:69:log_dist] [Rank -1] DeepSpeed info: version=0.6.5, git-hash=unknown, git-branch=unknown
# [2023-07-27 08:47:36,923] [INFO] [logging.py:69:log_dist] [Rank -1] DeepSpeed info: version=0.6.5, git-hash=unknown, git-branch=unknown
# [2023-07-27 08:47:36,930] [INFO] [distributed.py:48:init_distributed] Initializing torch distributed with backend: nccl
# [2023-07-27 08:47:36,950] [INFO] [logging.py:69:log_dist] [Rank -1] DeepSpeed info: version=0.6.5, git-hash=unknown, git-branch=unknown
# [2023-07-27 08:47:37,148] [INFO] [logging.py:69:log_dist] [Rank -1] DeepSpeed info: version=0.6.5, git-hash=unknown, git-branch=unknown
# [2023-07-27 08:47:40,600] [INFO] [engine.py:278:__init__] DeepSpeed Flops Profiler Enabled: False
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /home/admin/.cache/torch_extensions/py38_cu115/fused_adam/build.ninja...
# Building extension module fused_adam...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# ninja: no work to do.
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.11620521545410156 seconds
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10272622108459473 seconds
# [2023-07-27 08:47:41,183] [INFO] [engine.py:1100:_configure_optimizer] Using DeepSpeed Optimizer param name adam as basic optimizer
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# [2023-07-27 08:47:41,207] [INFO] [engine.py:1108:_configure_optimizer] DeepSpeed Basic Optimizer = FusedAdam
# [2023-07-27 08:47:41,207] [INFO] [utils.py:52:is_zero_supported_optimizer] Checking ZeRO support for optimizer=FusedAdam type=<class 'deepspeed.ops.adam.fused_adam.FusedAdam'>
# [2023-07-27 08:47:41,207] [INFO] [logging.py:69:log_dist] [Rank 0] Creating fp16 ZeRO stage 1 optimizer
# [2023-07-27 08:47:41,207] [INFO] [stage_1_and_2.py:133:__init__] Reduce bucket size 50000000
# [2023-07-27 08:47:41,208] [INFO] [stage_1_and_2.py:134:__init__] Allgather bucket size 50000000
# [2023-07-27 08:47:41,208] [INFO] [stage_1_and_2.py:135:__init__] CPU Offload: False
# [2023-07-27 08:47:41,208] [INFO] [stage_1_and_2.py:136:__init__] Round robin gradient partitioning: False
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.1023557186126709 seconds
# Emitting ninja build file /home/admin/.cache/torch_extensions/py38_cu115/utils/build.ninja...
# Building extension module utils...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# Loading extension module fused_adam...
# Time to load fused_adam op: 0.10289311408996582 seconds
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# ninja: no work to do.
# Loading extension module utils...
# Time to load utils op: 0.10733342170715332 seconds
# Loading extension module utils...
# Time to load utils op: 0.10211873054504395 seconds
# Loading extension module utils...
# Time to load utils op: 0.10169029235839844 seconds
# Loading extension module utils...
# Time to load utils op: 0.1024174690246582 seconds
# Rank: 0 partition count [4] and sizes[(15048202, False)]
# Rank: 1 partition count [4] and sizes[(15048202, False)]
# Rank: 2 partition count [4] and sizes[(15048202, False)]
# Rank: 3 partition count [4] and sizes[(15048202, False)]
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0003676414489746094 seconds
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.00047206878662109375 seconds
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0011625289916992188 seconds
# [2023-07-27 08:47:42,166] [INFO] [utils.py:828:see_memory_usage] Before initializing optimizer states
# [2023-07-27 08:47:42,167] [INFO] [utils.py:829:see_memory_usage] MA 0.17 GB         Max_MA 0.2 GB         CA 0.32 GB         Max_CA 0 GB
# [2023-07-27 08:47:42,167] [INFO] [utils.py:837:see_memory_usage] CPU Virtual Memory:  used = 18.28 GB, percent = 2.1%
# [2023-07-27 08:47:43,104] [INFO] [utils.py:828:see_memory_usage] After initializing optimizer states
# [2023-07-27 08:47:43,105] [INFO] [utils.py:829:see_memory_usage] MA 0.28 GB         Max_MA 0.34 GB         CA 0.49 GB         Max_CA 0 GB
# [2023-07-27 08:47:43,105] [INFO] [utils.py:837:see_memory_usage] CPU Virtual Memory:  used = 19.42 GB, percent = 2.2%
# [2023-07-27 08:47:43,105] [INFO] [stage_1_and_2.py:511:__init__] optimizer state initialized
# [2023-07-27 08:47:43,139] [INFO] [utils.py:828:see_memory_usage] After initializing ZeRO optimizer
# [2023-07-27 08:47:43,139] [INFO] [utils.py:829:see_memory_usage] MA 0.28 GB         Max_MA 0.28 GB         CA 0.49 GB         Max_CA 0 GB
# [2023-07-27 08:47:43,140] [INFO] [utils.py:837:see_memory_usage] CPU Virtual Memory:  used = 19.55 GB, percent = 2.3%
# [2023-07-27 08:47:43,140] [INFO] [logging.py:69:log_dist] [Rank 0] DeepSpeed Final Optimizer = adam
# [2023-07-27 08:47:43,140] [INFO] [engine.py:785:_configure_lr_scheduler] DeepSpeed using configured LR scheduler = WarmupLR
# [2023-07-27 08:47:43,140] [INFO] [logging.py:69:log_dist] [Rank 0] DeepSpeed LR Scheduler = <deepspeed.runtime.lr_schedules.WarmupLR object at 0x7f61d8500280>
# [2023-07-27 08:47:43,140] [INFO] [logging.py:69:log_dist] [Rank 0] step=0, skipped=0, lr=[0.001], mom=[[0.8, 0.999]]
# [2023-07-27 08:47:43,141] [INFO] [config.py:1059:print] DeepSpeedEngine configuration:
# [2023-07-27 08:47:43,141] [INFO] [config.py:1063:print]   activation_checkpointing_config  {
#     "partition_activations": false,
#     "contiguous_memory_optimization": false,
#     "cpu_checkpointing": false,
#     "number_checkpoints": 24,
#     "synchronize_checkpoint_boundary": false,
#     "profile": false
# }
# [2023-07-27 08:47:43,141] [INFO] [config.py:1063:print]   aio_config ................... {'block_size': 1048576, 'queue_depth': 8, 'thread_count': 1, 'single_submit': False, 'overlap_events': True}
# [2023-07-27 08:47:43,141] [INFO] [config.py:1063:print]   amp_enabled .................. False
# [2023-07-27 08:47:43,141] [INFO] [config.py:1063:print]   amp_params ................... False
# [2023-07-27 08:47:43,141] [INFO] [config.py:1063:print]   autotuning_config ............ {
#     "enabled": false,
#     "start_step": null,
#     "end_step": null,
#     "metric_path": null,
#     "arg_mappings": null,
#     "metric": "throughput",
#     "model_info": null,
#     "results_dir": null,
#     "exps_dir": null,
#     "overwrite": true,
#     "fast": true,
#     "start_profile_step": 3,
#     "end_profile_step": 5,
#     "tuner_type": "gridsearch",
#     "tuner_early_stopping": 5,
#     "tuner_num_trials": 50,
#     "model_info_path": null,
#     "mp_size": 1,
#     "max_train_batch_size": null,
#     "min_train_batch_size": 1,
#     "max_train_micro_batch_size_per_gpu": 1.024000e+03,
#     "min_train_micro_batch_size_per_gpu": 1,
#     "num_tuning_micro_batch_sizes": 3
# }
# [2023-07-27 08:47:43,141] [INFO] [config.py:1063:print]   bfloat16_enabled ............. False
# [2023-07-27 08:47:43,141] [INFO] [config.py:1063:print]   checkpoint_tag_validation_enabled  True
# [2023-07-27 08:47:43,141] [INFO] [config.py:1063:print]   checkpoint_tag_validation_fail  False
# [2023-07-27 08:47:43,141] [INFO] [config.py:1063:print]   communication_data_type ...... None
# [2023-07-27 08:47:43,141] [INFO] [config.py:1063:print]   curriculum_enabled ........... False
# [2023-07-27 08:47:43,141] [INFO] [config.py:1063:print]   curriculum_params ............ False
# [2023-07-27 08:47:43,141] [INFO] [config.py:1063:print]   dataloader_drop_last ......... False
# [2023-07-27 08:47:43,141] [INFO] [config.py:1063:print]   disable_allgather ............ False
# [2023-07-27 08:47:43,141] [INFO] [config.py:1063:print]   dump_state ................... False
# [2023-07-27 08:47:43,141] [INFO] [config.py:1063:print]   dynamic_loss_scale_args ...... {'init_scale': 32768, 'scale_window': 500, 'delayed_shift': 2, 'min_scale': 1}
# [2023-07-27 08:47:43,141] [INFO] [config.py:1063:print]   eigenvalue_enabled ........... False
# [2023-07-27 08:47:43,141] [INFO] [config.py:1063:print]   eigenvalue_gas_boundary_resolution  1
# [2023-07-27 08:47:43,141] [INFO] [config.py:1063:print]   eigenvalue_layer_name ........ bert.encoder.layer
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   eigenvalue_layer_num ......... 0
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   eigenvalue_max_iter .......... 100
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   eigenvalue_stability ......... 1e-06
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   eigenvalue_tol ............... 0.01
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   eigenvalue_verbose ........... False
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   elasticity_enabled ........... False
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   flops_profiler_config ........ {
#     "enabled": false,
#     "profile_step": 1,
#     "module_depth": -1,
#     "top_modules": 1,
#     "detailed": true,
#     "output_file": null
# }
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   fp16_enabled ................. True
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   fp16_master_weights_and_gradients  False
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   fp16_mixed_quantize .......... False
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   global_rank .................. 0
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   gradient_accumulation_steps .. 1
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   gradient_clipping ............ 1.0
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   gradient_predivide_factor .... 1.0
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   initial_dynamic_scale ........ 32768
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   loss_scale ................... 0
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   memory_breakdown ............. False
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   optimizer_legacy_fusion ...... False
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   optimizer_name ............... adam
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   optimizer_params ............. {'lr': 0.001, 'betas': [0.8, 0.999], 'eps': 1e-08, 'weight_decay': 3e-07}
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   pipeline ..................... {'stages': 'auto', 'partition': 'best', 'seed_layers': False, 'activation_checkpoint_interval': 0}
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   pld_enabled .................. False
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   pld_params ................... False
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   prescale_gradients ........... False
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   quantize_change_rate ......... 0.001
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   quantize_groups .............. 1
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   quantize_offset .............. 1000
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   quantize_period .............. 1000
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   quantize_rounding ............ 0
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   quantize_start_bits .......... 16
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   quantize_target_bits ......... 8
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   quantize_training_enabled .... False
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   quantize_type ................ 0
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   quantize_verbose ............. False
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   scheduler_name ............... WarmupLR
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   scheduler_params ............. {'warmup_min_lr': 0, 'warmup_max_lr': 0.001, 'warmup_num_steps': 1000}
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   sparse_attention ............. None
# [2023-07-27 08:47:43,142] [INFO] [config.py:1063:print]   sparse_gradients_enabled ..... False
# [2023-07-27 08:47:43,143] [INFO] [config.py:1063:print]   steps_per_print .............. 2000
# [2023-07-27 08:47:43,143] [INFO] [config.py:1063:print]   tensorboard_enabled .......... False
# [2023-07-27 08:47:43,143] [INFO] [config.py:1063:print]   tensorboard_job_name ......... DeepSpeedJobName
# [2023-07-27 08:47:43,143] [INFO] [config.py:1063:print]   tensorboard_output_path ......
# [2023-07-27 08:47:43,143] [INFO] [config.py:1063:print]   train_batch_size ............. 512
# [2023-07-27 08:47:43,143] [INFO] [config.py:1063:print]   train_micro_batch_size_per_gpu  128
# [2023-07-27 08:47:43,143] [INFO] [config.py:1063:print]   use_quantizer_kernel ......... False
# [2023-07-27 08:47:43,143] [INFO] [config.py:1063:print]   wall_clock_breakdown ......... False
# [2023-07-27 08:47:43,143] [INFO] [config.py:1063:print]   world_size ................... 4
# [2023-07-27 08:47:43,143] [INFO] [config.py:1063:print]   zero_allow_untested_optimizer  False
# [2023-07-27 08:47:43,143] [INFO] [config.py:1063:print]   zero_config .................. {
#     "stage": 1,
#     "contiguous_gradients": true,
#     "reduce_scatter": true,
#     "reduce_bucket_size": 5.000000e+07,
#     "allgather_partitions": true,
#     "allgather_bucket_size": 5.000000e+07,
#     "overlap_comm": true,
#     "load_from_fp32_weights": true,
#     "elastic_checkpoint": false,
#     "offload_param": null,
#     "offload_optimizer": null,
#     "sub_group_size": 1.000000e+09,
#     "prefetch_bucket_size": 5.000000e+07,
#     "param_persistence_threshold": 1.000000e+05,
#     "max_live_parameters": 1.000000e+09,
#     "max_reuse_distance": 1.000000e+09,
#     "gather_16bit_weights_on_model_save": false,
#     "ignore_unused_parameters": true,
#     "round_robin_gradients": false,
#     "legacy_stage1": false
# }
# [2023-07-27 08:47:43,143] [INFO] [config.py:1063:print]   zero_enabled ................. True
# [2023-07-27 08:47:43,143] [INFO] [config.py:1063:print]   zero_optimization_stage ...... 1
# [2023-07-27 08:47:43,143] [INFO] [config.py:1065:print]   json = {
#     "train_batch_size": 512,
#     "steps_per_print": 2.000000e+03,
#     "optimizer": {
#         "type": "Adam",
#         "params": {
#             "lr": 0.001,
#             "betas": [0.8, 0.999],
#             "eps": 1e-08,
#             "weight_decay": 3e-07
#         }
#     },
#     "scheduler": {
#         "type": "WarmupLR",
#         "params": {
#             "warmup_min_lr": 0,
#             "warmup_max_lr": 0.001,
#             "warmup_num_steps": 1000
#         }
#     },
#     "gradient_clipping": 1.0,
#     "prescale_gradients": false,
#     "fp16": {
#         "enabled": true,
#         "fp16_master_weights_and_grads": false,
#         "loss_scale": 0,
#         "loss_scale_window": 500,
#         "hysteresis": 2,
#         "min_loss_scale": 1,
#         "initial_scale_power": 15
#     },
#     "wall_clock_breakdown": false,
#     "activation_checkpointing": {
#         "partition_activations": false,
#         "cpu_checkpointing": false,
#         "contiguous_memory_optimization": false,
#         "number_checkpoints": 24,
#         "synchronize_checkpoint_boundary": false,
#         "profile": false
#     },
#     "zero_optimization": {
#         "stage": 1,
#         "allgather_partitions": true,
#         "reduce_scatter": true,
#         "allgather_bucket_size": 5.000000e+07,
#         "reduce_bucket_size": 5.000000e+07,
#         "overlap_comm": true,
#         "contiguous_gradients": true,
#         "cpu_offload": false
#     }
# }
# Using /home/admin/.cache/torch_extensions/py38_cu115 as PyTorch extensions root...
# No modifications detected for re-loaded extension module utils, skipping build step...
# Loading extension module utils...
# Time to load utils op: 0.0003159046173095703 seconds
# [2023-07-27 08:47:46,003] [INFO] [stage_1_and_2.py:1671:step] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 32768, reducing to 32768
# [2023-07-27 08:47:46,253] [INFO] [stage_1_and_2.py:1671:step] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 32768, reducing to 16384.0
# [2023-07-27 08:47:47,434] [INFO] [stage_1_and_2.py:1671:step] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 16384.0, reducing to 8192.0
# [2023-07-27 08:47:47,804] [INFO] [stage_1_and_2.py:1671:step] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 8192.0, reducing to 4096.0
# [2023-07-27 08:48:09,665] [INFO] [stage_1_and_2.py:1671:step] [deepspeed] OVERFLOW! Rank 0 Skipping step. Attempted loss scale: 4096.0, reducing to 2048.0
# Training Done
# Training Done
# Training Done
# Training Done
# [2023-07-27 08:48:12,700] [INFO] [launch.py:210:main] Process 11495 exits successfully.
# [2023-07-27 08:48:12,700] [INFO] [launch.py:210:main] Process 11497 exits successfully.
# [2023-07-27 08:48:12,701] [INFO] [launch.py:210:main] Process 11496 exits successfully.
# [2023-07-27 08:48:12,701] [INFO] [launch.py:210:main] Process 11498 exits successfully.

# %% [markdown]
# Compared to the run without ZeRO, Stage 1 allows to reduce the GPU memory usage from about 1.5GB to 1GB as it partitions the optimizer states across 4 GPUs meaning that each GPU is responsible for keeping in memory a part of the optimizer states and communicate them when necessary to others. In this case, no significant extra time is observed to run the step with ZeRO Stage 1.

# %% [markdown]
# ## Optional: 5.2.4  Autotuning
#
# When designing training experiments, it is hard to know what are the best configurations (such as micro-batch size) that fully utilize the hardware and achieve a high throughput number. Usually, configuration exploration is performed manually. This tuning process can be painful, time-consuming and the configurations are hardware-dependent. The DeepSpeed Autotuner automatically discovers the optimal DeepSpeed configuration parameters that optimizes for training speed.
# To launch the autotuning, add `--autotuning run` command to the training script and enable it on the configuration file as follows:
#
# ```
# {
#   "train_micro_batch_size_per_gpu": "auto",
#
#   "autotuning": {
#     "enabled": true,
#     "arg_mappings": {
#       "train_micro_batch_size_per_gpu": "--batch_size"    }
#   }
# }
# ```
# The arg_mappings dictionary autotuning section of the DeepSpeed configuration file provides the naming mappings between the parameters in DeepSpeed configuration and the training script arguments. It is also possible restrict the search space to a list of values by replacing "auto" with a vector of possible values to be evaluated.
#
# To learn more about the Autotuning feature, check the [DeepSpeed documentation](https://www.deepspeed.ai/tutorials/autotuning/)

# %% [markdown]
# ---
# <h2 style="color:green;">Congratulations!</h2>
#
# Before moving on, we need to make sure no jobs are still running or waiting in the queue.

# %%
# Check the SLURM jobs queue 
# !squeue
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)

# %% [markdown]
# If there are still jobs running or pending, execute the following cell to cancel all the admin user's jobs using the `scancel` command.

# %%
# Cancel admin user jobs
# !scancel -u $USER

# Check again the SLURM jobs queue (should be either empty, or the status TS column should be CG)
# !squeue
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)

# %% [markdown]
# Next, we will see Mixture of Expert (MOE)configurations. Move on to [06_MOE_alternative_models.ipynb](06_MOE_alternative_models.ipynb).
